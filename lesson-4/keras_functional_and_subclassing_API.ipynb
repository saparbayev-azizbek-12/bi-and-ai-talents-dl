# %% [markdown]
# ## Functional API

# %%
from tensorflow.keras.datasets import california_housing

(X_train, y_train), (X_test, y_test) = california_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/california_housing.npz
# 743530/743530 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Normalization, Input, Concatenate

input_ = Input(shape=[8], name='input')
norm_layer = Normalization(name='normalization')
hidden_layer1 = Dense(16, activation='relu', name='hidden1')
hidden_layer2 = Dense(16, activation='relu', name='hidden2')
hidden_layer3 = Dense(24, activation='relu', name='hidden3')
concat_layer1 = Concatenate(name='concat1')
concat_layer2 = Concatenate(name='concat2')
output_layer = Dense(1, name='output')

norm = norm_layer(input_)
hidden1 = hidden_layer1(norm)
hidden2 = hidden_layer2(hidden1)
concat1 = concat_layer1([input_, hidden2])
hidden3 = hidden_layer3(input_)
concat2 = concat_layer2([hidden3, concat1])
output = output_layer(concat2)

model = Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 8)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 8)         │         17 │ input[0][0]       │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden1 (Dense)     │ (None, 16)        │        144 │ normalization[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden2 (Dense)     │ (None, 16)        │        272 │ hidden1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden3 (Dense)     │ (None, 24)        │        216 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat1             │ (None, 24)        │          0 │ input[0][0],      │
# │ (Concatenate)       │                   │            │ hidden2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat2             │ (None, 48)        │          0 │ hidden3[0][0],    │
# │ (Concatenate)       │                   │            │ concat1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │         49 │ concat2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 698 (2.73 KB)
#  Trainable params: 681 (2.66 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
model.save('deep_and_wide_model_v2.keras')

# %% [markdown]
# ## Subclass API

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras.layers import Dense, Normalization, Input, Concatenate

@register_keras_serializable()
class MySubclassAPI(Model):
  def __init__(self, shape, units=16, activation='relu', **kwargs):
    super().__init__(**kwargs)
    self.norm_layer = Normalization()
    self.hidden_layer1 = Dense(units, activation=activation, name='hidden1')
    self.hidden_layer2 = Dense(units, activation=activation, name='hidden2')
    self.hidden_layer3 = Dense(24, activation=activation, name='hidden3')
    self.concat_layer1 = Concatenate(name='concat1')
    self.concat_layer2 = Concatenate(name='concat2')
    self.output_layer = Dense(1, name='output')

  def call(self, X):
    norm = self.norm_layer(X)
    hidden1 = self.hidden_layer1(norm)
    hidden2 = self.hidden_layer2(hidden1)
    concat1 = self.concat_layer1([X, hidden2])
    hidden3 = self.hidden_layer3(X)
    concat2 = self.concat_layer2([hidden3, concat1])
    output = self.output_layer(concat2)
    return output

# %%
from tensorflow.keras.optimizers import SGD, Adam

sub_model = MySubclassAPI(shape=8, units=16)
sub_model.norm_layer.adapt(X_train)
optimizer = Adam(learning_rate=0.001)
sub_model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])

# %%
sub_model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - RootMeanSquaredError: 232787.5156 - loss: 54211993600.0000 - val_RootMeanSquaredError: 211594.5000 - val_loss: 44772233216.0000
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 201188.6094 - loss: 40533897216.0000 - val_RootMeanSquaredError: 174896.0938 - val_loss: 30588645376.0000
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 169426.6406 - loss: 28710397952.0000 - val_RootMeanSquaredError: 165399.4688 - val_loss: 27356983296.0000
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 160244.8594 - loss: 25683120128.0000 - val_RootMeanSquaredError: 161664.2031 - val_loss: 26135316480.0000
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 156849.2812 - loss: 24605552640.0000 - val_RootMeanSquaredError: 156478.5469 - val_loss: 24485535744.0000
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 151705.7188 - loss: 23024793600.0000 - val_RootMeanSquaredError: 149822.1562 - val_loss: 22446678016.0000
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 145991.8750 - loss: 21337192448.0000 - val_RootMeanSquaredError: 141935.7812 - val_loss: 20145766400.0000
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 138046.2031 - loss: 19072098304.0000 - val_RootMeanSquaredError: 133517.9531 - val_loss: 17827045376.0000
# Epoch 9/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 127488.2891 - loss: 16269089792.0000 - val_RootMeanSquaredError: 125122.9062 - val_loss: 15655741440.0000
# Epoch 10/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 121045.3125 - loss: 14654200832.0000 - val_RootMeanSquaredError: 117706.8047 - val_loss: 13854892032.0000
# Epoch 11/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 114231.1406 - loss: 13059344384.0000 - val_RootMeanSquaredError: 111485.7891 - val_loss: 12429080576.0000
# Epoch 12/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 107926.4297 - loss: 11653487616.0000 - val_RootMeanSquaredError: 106552.9297 - val_loss: 11353527296.0000
# Epoch 13/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 103351.8438 - loss: 10686203904.0000 - val_RootMeanSquaredError: 102655.0156 - val_loss: 10538052608.0000
# Epoch 14/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 102208.3438 - loss: 10450705408.0000 - val_RootMeanSquaredError: 99315.5391 - val_loss: 9863575552.0000
# Epoch 15/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 98760.6094 - loss: 9757010944.0000 - val_RootMeanSquaredError: 96237.9219 - val_loss: 9261736960.0000
# Epoch 16/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 94737.6172 - loss: 8976327680.0000 - val_RootMeanSquaredError: 93347.6094 - val_loss: 8713776128.0000
# Epoch 17/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 94017.6562 - loss: 8841619456.0000 - val_RootMeanSquaredError: 90769.5469 - val_loss: 8239110144.0000
# Epoch 18/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 93276.5156 - loss: 8713863168.0000 - val_RootMeanSquaredError: 88428.4766 - val_loss: 7819595264.0000
# Epoch 19/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 90697.9922 - loss: 8233689088.0000 - val_RootMeanSquaredError: 86296.3125 - val_loss: 7447053312.0000
# Epoch 20/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 87035.2734 - loss: 7577051136.0000 - val_RootMeanSquaredError: 84392.7188 - val_loss: 7122130944.0000
# Epoch 21/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 84030.2969 - loss: 7062460928.0000 - val_RootMeanSquaredError: 82704.9453 - val_loss: 6840107520.0000
# Epoch 22/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 83611.2500 - loss: 6996531712.0000 - val_RootMeanSquaredError: 81288.8203 - val_loss: 6607872000.0000
# Epoch 23/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 81615.2422 - loss: 6664865792.0000 - val_RootMeanSquaredError: 79998.4922 - val_loss: 6399759360.0000
# Epoch 24/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 82368.5859 - loss: 6793511424.0000 - val_RootMeanSquaredError: 78717.6328 - val_loss: 6196465152.0000
# Epoch 25/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 78483.8047 - loss: 6164566016.0000 - val_RootMeanSquaredError: 77586.9375 - val_loss: 6019732480.0000
# Epoch 26/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 79425.9062 - loss: 6312396288.0000 - val_RootMeanSquaredError: 76513.2656 - val_loss: 5854280192.0000
# Epoch 27/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 78150.0781 - loss: 6110328832.0000 - val_RootMeanSquaredError: 75487.6016 - val_loss: 5698377728.0000
# Epoch 28/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 76410.9453 - loss: 5841462272.0000 - val_RootMeanSquaredError: 74618.5312 - val_loss: 5567925248.0000
# Epoch 29/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 76065.0312 - loss: 5786887168.0000 - val_RootMeanSquaredError: 73694.5156 - val_loss: 5430881280.0000
# Epoch 30/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 74886.9062 - loss: 5608827392.0000 - val_RootMeanSquaredError: 72983.8438 - val_loss: 5326641664.0000
# Epoch 31/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 73491.9688 - loss: 5402365440.0000 - val_RootMeanSquaredError: 72131.6719 - val_loss: 5202978304.0000
# Epoch 32/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 72657.4141 - loss: 5280160256.0000 - val_RootMeanSquaredError: 71498.7734 - val_loss: 5112074240.0000
# Epoch 33/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 71918.2891 - loss: 5177592320.0000 - val_RootMeanSquaredError: 70886.6094 - val_loss: 5024911360.0000
# Epoch 34/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 72619.9062 - loss: 5277280768.0000 - val_RootMeanSquaredError: 70356.8438 - val_loss: 4950085632.0000
# Epoch 35/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 72023.1484 - loss: 5190795776.0000 - val_RootMeanSquaredError: 69958.3828 - val_loss: 4894175232.0000
# Epoch 36/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 70564.5234 - loss: 4981882368.0000 - val_RootMeanSquaredError: 69554.6641 - val_loss: 4837851648.0000
# Epoch 37/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 71228.9688 - loss: 5075635200.0000 - val_RootMeanSquaredError: 69181.8125 - val_loss: 4786123264.0000
# Epoch 38/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 70842.1719 - loss: 5020701696.0000 - val_RootMeanSquaredError: 68897.9766 - val_loss: 4746931712.0000
# Epoch 39/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68460.0000 - loss: 4689198592.0000 - val_RootMeanSquaredError: 68665.9141 - val_loss: 4715007488.0000
# Epoch 40/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 69917.0391 - loss: 4892750336.0000 - val_RootMeanSquaredError: 68431.4766 - val_loss: 4682867200.0000
# Epoch 41/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 69321.6406 - loss: 4806918144.0000 - val_RootMeanSquaredError: 68251.8672 - val_loss: 4658317824.0000
# Epoch 42/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 68872.7656 - loss: 4744306176.0000 - val_RootMeanSquaredError: 68115.5469 - val_loss: 4639728128.0000
# Epoch 43/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68825.6094 - loss: 4737834496.0000 - val_RootMeanSquaredError: 67974.7812 - val_loss: 4620571136.0000
# Epoch 44/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 69171.7812 - loss: 4785860608.0000 - val_RootMeanSquaredError: 67837.0391 - val_loss: 4601863680.0000
# Epoch 45/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 70353.3359 - loss: 4954923008.0000 - val_RootMeanSquaredError: 67693.7578 - val_loss: 4582444544.0000
# Epoch 46/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 68257.2109 - loss: 4660406272.0000 - val_RootMeanSquaredError: 67606.6562 - val_loss: 4570659840.0000
# Epoch 47/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 69127.5547 - loss: 4781095936.0000 - val_RootMeanSquaredError: 67507.5703 - val_loss: 4557272576.0000
# Epoch 48/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - RootMeanSquaredError: 69323.3125 - loss: 4808232448.0000 - val_RootMeanSquaredError: 67397.3438 - val_loss: 4542401536.0000
# Epoch 49/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67709.0078 - loss: 4586884096.0000 - val_RootMeanSquaredError: 67313.1719 - val_loss: 4531063296.0000
# Epoch 50/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 68610.4609 - loss: 4708141568.0000 - val_RootMeanSquaredError: 67221.3281 - val_loss: 4518707200.0000
# Epoch 51/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68252.8438 - loss: 4662116864.0000 - val_RootMeanSquaredError: 67190.3438 - val_loss: 4514542080.0000
# Epoch 52/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67231.6953 - loss: 4521956352.0000 - val_RootMeanSquaredError: 67062.4531 - val_loss: 4497372672.0000
# Epoch 53/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67991.1328 - loss: 4625675264.0000 - val_RootMeanSquaredError: 67007.6719 - val_loss: 4490028544.0000
# Epoch 54/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68451.4297 - loss: 4687781376.0000 - val_RootMeanSquaredError: 66918.8516 - val_loss: 4478132736.0000
# Epoch 55/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 69253.4688 - loss: 4798843392.0000 - val_RootMeanSquaredError: 66857.7812 - val_loss: 4469962752.0000
# Epoch 56/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67278.8516 - loss: 4528366592.0000 - val_RootMeanSquaredError: 66805.3750 - val_loss: 4462958080.0000
# Epoch 57/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67278.7344 - loss: 4527281664.0000 - val_RootMeanSquaredError: 66719.9297 - val_loss: 4451548672.0000
# Epoch 58/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67972.6406 - loss: 4623800320.0000 - val_RootMeanSquaredError: 66666.0703 - val_loss: 4444365312.0000
# Epoch 59/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67990.5781 - loss: 4624320000.0000 - val_RootMeanSquaredError: 66603.8125 - val_loss: 4436068352.0000
# Epoch 60/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66427.7344 - loss: 4415646720.0000 - val_RootMeanSquaredError: 66541.0938 - val_loss: 4427717120.0000
# Epoch 61/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67838.6016 - loss: 4606235648.0000 - val_RootMeanSquaredError: 66499.5156 - val_loss: 4422185472.0000
# Epoch 62/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67341.7734 - loss: 4537551872.0000 - val_RootMeanSquaredError: 66439.9062 - val_loss: 4414261248.0000
# Epoch 63/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66008.8516 - loss: 4358296576.0000 - val_RootMeanSquaredError: 66447.6250 - val_loss: 4415286784.0000
# Epoch 64/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67117.0781 - loss: 4505862656.0000 - val_RootMeanSquaredError: 66330.4531 - val_loss: 4399729152.0000
# Epoch 65/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68724.3125 - loss: 4725530624.0000 - val_RootMeanSquaredError: 66270.0625 - val_loss: 4391720960.0000
# Epoch 66/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66604.4219 - loss: 4438624256.0000 - val_RootMeanSquaredError: 66190.1172 - val_loss: 4381131264.0000
# Epoch 67/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67752.3828 - loss: 4594077696.0000 - val_RootMeanSquaredError: 66140.7891 - val_loss: 4374604288.0000
# Epoch 68/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67223.8906 - loss: 4520278528.0000 - val_RootMeanSquaredError: 66081.0625 - val_loss: 4366707200.0000
# Epoch 69/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67449.1172 - loss: 4553081344.0000 - val_RootMeanSquaredError: 66067.3438 - val_loss: 4364893696.0000
# Epoch 70/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66851.6172 - loss: 4469727744.0000 - val_RootMeanSquaredError: 65977.3203 - val_loss: 4353007104.0000
# Epoch 71/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67487.4219 - loss: 4557972992.0000 - val_RootMeanSquaredError: 65932.6562 - val_loss: 4347115008.0000
# Epoch 72/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66302.0469 - loss: 4397553664.0000 - val_RootMeanSquaredError: 65861.5391 - val_loss: 4337742336.0000
# Epoch 73/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66838.1719 - loss: 4468280832.0000 - val_RootMeanSquaredError: 65800.5625 - val_loss: 4329713664.0000
# Epoch 74/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65893.5547 - loss: 4343452160.0000 - val_RootMeanSquaredError: 65773.3281 - val_loss: 4326131200.0000
# Epoch 75/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65764.7812 - loss: 4328235008.0000 - val_RootMeanSquaredError: 65760.8438 - val_loss: 4324488704.0000
# Epoch 76/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65480.1680 - loss: 4288266496.0000 - val_RootMeanSquaredError: 65670.1641 - val_loss: 4312570368.0000
# Epoch 77/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66367.7344 - loss: 4406670848.0000 - val_RootMeanSquaredError: 65639.9219 - val_loss: 4308599296.0000
# Epoch 78/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67161.9219 - loss: 4512023552.0000 - val_RootMeanSquaredError: 65564.4219 - val_loss: 4298693120.0000
# Epoch 79/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66106.8516 - loss: 4371895808.0000 - val_RootMeanSquaredError: 65527.1328 - val_loss: 4293805056.0000
# Epoch 80/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 64976.6406 - loss: 4226725376.0000 - val_RootMeanSquaredError: 65465.7266 - val_loss: 4285761536.0000
# Epoch 81/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67073.2891 - loss: 4505331712.0000 - val_RootMeanSquaredError: 65521.2734 - val_loss: 4293037056.0000
# Epoch 82/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66056.4062 - loss: 4365356032.0000 - val_RootMeanSquaredError: 65385.8359 - val_loss: 4275307776.0000
# Epoch 83/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66473.1719 - loss: 4420333568.0000 - val_RootMeanSquaredError: 65326.6406 - val_loss: 4267569920.0000
# Epoch 84/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66027.5078 - loss: 4361426944.0000 - val_RootMeanSquaredError: 65339.6719 - val_loss: 4269272832.0000
# Epoch 85/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65565.7266 - loss: 4300865536.0000 - val_RootMeanSquaredError: 65283.6523 - val_loss: 4261955328.0000
# Epoch 86/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65663.6719 - loss: 4313496576.0000 - val_RootMeanSquaredError: 65208.6875 - val_loss: 4252172800.0000
# Epoch 87/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65772.6875 - loss: 4326561280.0000 - val_RootMeanSquaredError: 65159.2812 - val_loss: 4245731840.0000
# Epoch 88/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65006.4219 - loss: 4226765568.0000 - val_RootMeanSquaredError: 65183.1250 - val_loss: 4248839680.0000
# Epoch 89/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64340.2344 - loss: 4142801664.0000 - val_RootMeanSquaredError: 65191.8672 - val_loss: 4249979392.0000
# Epoch 90/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65790.3906 - loss: 4329627136.0000 - val_RootMeanSquaredError: 65039.6641 - val_loss: 4230158080.0000
# Epoch 91/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 66390.6875 - loss: 4411426816.0000 - val_RootMeanSquaredError: 65010.7852 - val_loss: 4226402304.0000
# Epoch 92/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 65089.5117 - loss: 4237972992.0000 - val_RootMeanSquaredError: 65002.6602 - val_loss: 4225345792.0000
# Epoch 93/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65148.8711 - loss: 4244848640.0000 - val_RootMeanSquaredError: 64937.4609 - val_loss: 4216873984.0000
# Epoch 94/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65502.9102 - loss: 4292408320.0000 - val_RootMeanSquaredError: 64919.1523 - val_loss: 4214496256.0000
# Epoch 95/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65271.1484 - loss: 4261195776.0000 - val_RootMeanSquaredError: 64870.3047 - val_loss: 4208156416.0000
# Epoch 96/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66138.9531 - loss: 4375283712.0000 - val_RootMeanSquaredError: 64843.8672 - val_loss: 4204727296.0000
# Epoch 97/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64640.3516 - loss: 4179408128.0000 - val_RootMeanSquaredError: 64838.3828 - val_loss: 4204016128.0000
# Epoch 98/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65321.7070 - loss: 4268398080.0000 - val_RootMeanSquaredError: 64854.2266 - val_loss: 4206070784.0000
# Epoch 99/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65305.0703 - loss: 4265967360.0000 - val_RootMeanSquaredError: 64737.1328 - val_loss: 4190896128.0000
# Epoch 100/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 64053.6797 - loss: 4105214720.0000 - val_RootMeanSquaredError: 64726.9062 - val_loss: 4189572608.0000

# %%
sub_model.save("drive/MyDrive/MySubmodelAPI.keras")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)

# %% [markdown]
# ## Test Custom Model

# %%
y_pred = sub_model.predict(X_test).reshape(y_test.shape[0])
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred[:5], y_test[:5]
# Out:
# (array([226671.95, 299055.06, 185373.84, 324483.12, 219379.69],
#        dtype=float32),
#  array([397900., 227900., 172100., 186500., 148900.], dtype=float32))

# %% [markdown]
# ## Simple Verion of the Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras.layers import Dense, Normalization, Input, Concatenate, Dropout

@register_keras_serializable()
class MySubclassAPI(Model):
  def __init__(self, shape, units=16, activation='relu', **kwargs):
    super().__init__(**kwargs)
    self.norm_layer = Normalization()
    self.hidden_layer1 = Dense(units, activation=activation, name='hidden1')
    self.hidden_layer2 = Dense(units, activation=activation, name='hidden2')
    self.hidden_layer3 = Dense(units, activation=activation, name='hidden3')
    self.dropout = Dropout(0.2)
    self.output_layer = Dense(1, name='output')

  def call(self, X):
    norm = self.norm_layer(X)
    hidden1 = self.hidden_layer1(norm)
    hidden2 = self.hidden_layer2(hidden1)
    hidden3 = self.hidden_layer3(hidden2)
    output = self.output_layer(hidden3)
    return output

# %%
from tensorflow.keras.optimizers import SGD, Adam

sub_model = MySubclassAPI(shape=8, units=32)
sub_model.norm_layer.adapt(X_train)
optimizer = Adam(learning_rate=0.0005)
sub_model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])

# %%
sub_model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - RootMeanSquaredError: 234999.5156 - loss: 55228813312.0000 - val_RootMeanSquaredError: 236719.5625 - val_loss: 56036151296.0000
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 231962.2344 - loss: 53822496768.0000 - val_RootMeanSquaredError: 216709.9688 - val_loss: 46963212288.0000
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 203447.3750 - loss: 41443876864.0000 - val_RootMeanSquaredError: 161020.6250 - val_loss: 25927643136.0000
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 144687.9219 - loss: 20962955264.0000 - val_RootMeanSquaredError: 120040.0312 - val_loss: 14409608192.0000
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 116792.3516 - loss: 13645087744.0000 - val_RootMeanSquaredError: 109199.9453 - val_loss: 11924627456.0000
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 107467.7734 - loss: 11551296512.0000 - val_RootMeanSquaredError: 102358.3750 - val_loss: 10477237248.0000
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 100765.0938 - loss: 10157741056.0000 - val_RootMeanSquaredError: 96929.8672 - val_loss: 9395399680.0000
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 96444.1719 - loss: 9308011520.0000 - val_RootMeanSquaredError: 92395.6172 - val_loss: 8536950784.0000
# Epoch 9/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 91900.7656 - loss: 8446942208.0000 - val_RootMeanSquaredError: 88525.1094 - val_loss: 7836694528.0000
# Epoch 10/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 87820.5078 - loss: 7715326464.0000 - val_RootMeanSquaredError: 85249.6875 - val_loss: 7267509248.0000
# Epoch 11/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 86467.4219 - loss: 7483802624.0000 - val_RootMeanSquaredError: 82305.3750 - val_loss: 6774174208.0000
# Epoch 12/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 83631.7266 - loss: 7000328704.0000 - val_RootMeanSquaredError: 79786.0000 - val_loss: 6365806080.0000
# Epoch 13/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 81515.8672 - loss: 6648952832.0000 - val_RootMeanSquaredError: 77616.0000 - val_loss: 6024243200.0000
# Epoch 14/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 77501.1016 - loss: 6010703360.0000 - val_RootMeanSquaredError: 75806.5703 - val_loss: 5746636288.0000
# Epoch 15/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 76584.8828 - loss: 5869135360.0000 - val_RootMeanSquaredError: 74172.2109 - val_loss: 5501516800.0000
# Epoch 16/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 75710.9453 - loss: 5734339072.0000 - val_RootMeanSquaredError: 72800.4531 - val_loss: 5299905536.0000
# Epoch 17/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 74267.9453 - loss: 5517747712.0000 - val_RootMeanSquaredError: 71733.6250 - val_loss: 5145713152.0000
# Epoch 18/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 74286.6484 - loss: 5529895936.0000 - val_RootMeanSquaredError: 70651.0078 - val_loss: 4991565312.0000
# Epoch 19/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 71009.6172 - loss: 5043662336.0000 - val_RootMeanSquaredError: 69794.8203 - val_loss: 4871316992.0000
# Epoch 20/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 70657.1719 - loss: 4994004992.0000 - val_RootMeanSquaredError: 69140.0156 - val_loss: 4780342272.0000
# Epoch 21/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 69543.5078 - loss: 4837241856.0000 - val_RootMeanSquaredError: 68606.3750 - val_loss: 4706834944.0000
# Epoch 22/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 70531.3750 - loss: 4975665664.0000 - val_RootMeanSquaredError: 68121.3516 - val_loss: 4640518656.0000
# Epoch 23/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 69978.2266 - loss: 4904817152.0000 - val_RootMeanSquaredError: 67731.1250 - val_loss: 4587505664.0000
# Epoch 24/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 69239.5469 - loss: 4794950144.0000 - val_RootMeanSquaredError: 67409.3672 - val_loss: 4544022528.0000
# Epoch 25/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 68583.9922 - loss: 4707918336.0000 - val_RootMeanSquaredError: 67151.9609 - val_loss: 4509385728.0000
# Epoch 26/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 68320.0156 - loss: 4668823040.0000 - val_RootMeanSquaredError: 66954.9062 - val_loss: 4482959360.0000
# Epoch 27/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67681.2188 - loss: 4582957056.0000 - val_RootMeanSquaredError: 66789.5234 - val_loss: 4460839936.0000
# Epoch 28/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67559.1016 - loss: 4565543936.0000 - val_RootMeanSquaredError: 66593.6562 - val_loss: 4434715136.0000
# Epoch 29/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67938.3672 - loss: 4616670208.0000 - val_RootMeanSquaredError: 66525.0312 - val_loss: 4425580032.0000
# Epoch 30/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67716.5703 - loss: 4588449792.0000 - val_RootMeanSquaredError: 66425.9141 - val_loss: 4412402176.0000
# Epoch 31/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 68120.7344 - loss: 4645873664.0000 - val_RootMeanSquaredError: 66307.0703 - val_loss: 4396627968.0000
# Epoch 32/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 67570.7969 - loss: 4572768256.0000 - val_RootMeanSquaredError: 66220.4375 - val_loss: 4385145856.0000
# Epoch 33/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 65628.1797 - loss: 4310919680.0000 - val_RootMeanSquaredError: 66152.7031 - val_loss: 4376180224.0000
# Epoch 34/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65849.8438 - loss: 4338484736.0000 - val_RootMeanSquaredError: 66087.4922 - val_loss: 4367556608.0000
# Epoch 35/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 68535.5000 - loss: 4699207680.0000 - val_RootMeanSquaredError: 66066.9609 - val_loss: 4364843008.0000
# Epoch 36/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67551.4219 - loss: 4564568576.0000 - val_RootMeanSquaredError: 65988.8438 - val_loss: 4354527232.0000
# Epoch 37/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66088.0938 - loss: 4371169792.0000 - val_RootMeanSquaredError: 65946.4844 - val_loss: 4348938752.0000
# Epoch 38/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67238.2969 - loss: 4522104320.0000 - val_RootMeanSquaredError: 65943.3906 - val_loss: 4348531200.0000
# Epoch 39/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66367.1797 - loss: 4406633984.0000 - val_RootMeanSquaredError: 65852.0547 - val_loss: 4336493056.0000
# Epoch 40/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 67106.8359 - loss: 4504244736.0000 - val_RootMeanSquaredError: 65842.8203 - val_loss: 4335277056.0000
# Epoch 41/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65434.7070 - loss: 4284496896.0000 - val_RootMeanSquaredError: 65760.0469 - val_loss: 4324383744.0000
# Epoch 42/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66697.6797 - loss: 4449226240.0000 - val_RootMeanSquaredError: 65718.0391 - val_loss: 4318860800.0000
# Epoch 43/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 66123.9922 - loss: 4373142016.0000 - val_RootMeanSquaredError: 65721.1406 - val_loss: 4319267840.0000
# Epoch 44/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 65136.8203 - loss: 4244612608.0000 - val_RootMeanSquaredError: 65698.4141 - val_loss: 4316281856.0000
# Epoch 45/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66159.4844 - loss: 4380177920.0000 - val_RootMeanSquaredError: 65719.0547 - val_loss: 4318993920.0000
# Epoch 46/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66417.4531 - loss: 4412278784.0000 - val_RootMeanSquaredError: 65693.9219 - val_loss: 4315691520.0000
# Epoch 47/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67261.5391 - loss: 4528029184.0000 - val_RootMeanSquaredError: 65575.3125 - val_loss: 4300122112.0000
# Epoch 48/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65207.2539 - loss: 4253539840.0000 - val_RootMeanSquaredError: 65581.0625 - val_loss: 4300875776.0000
# Epoch 49/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65617.7031 - loss: 4306544128.0000 - val_RootMeanSquaredError: 65566.1172 - val_loss: 4298915328.0000
# Epoch 50/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66308.3047 - loss: 4400031744.0000 - val_RootMeanSquaredError: 65537.8438 - val_loss: 4295208960.0000
# Epoch 51/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65659.6328 - loss: 4311987200.0000 - val_RootMeanSquaredError: 65556.9766 - val_loss: 4297717248.0000
# Epoch 52/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65240.9727 - loss: 4258426880.0000 - val_RootMeanSquaredError: 65486.6680 - val_loss: 4288503552.0000
# Epoch 53/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66581.3125 - loss: 4436526080.0000 - val_RootMeanSquaredError: 65500.0195 - val_loss: 4290252800.0000
# Epoch 54/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65808.7422 - loss: 4331194368.0000 - val_RootMeanSquaredError: 65454.3594 - val_loss: 4284273408.0000
# Epoch 55/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 66647.2422 - loss: 4443726848.0000 - val_RootMeanSquaredError: 65432.6680 - val_loss: 4281434112.0000
# Epoch 56/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 65127.7930 - loss: 4242964480.0000 - val_RootMeanSquaredError: 65430.5117 - val_loss: 4281152000.0000
# Epoch 57/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65157.7305 - loss: 4246690816.0000 - val_RootMeanSquaredError: 65429.1641 - val_loss: 4280975616.0000
# Epoch 58/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64413.2031 - loss: 4151591168.0000 - val_RootMeanSquaredError: 65340.3203 - val_loss: 4269357568.0000
# Epoch 59/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 64490.0469 - loss: 4162028288.0000 - val_RootMeanSquaredError: 65441.4375 - val_loss: 4282581760.0000
# Epoch 60/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65254.1367 - loss: 4259751168.0000 - val_RootMeanSquaredError: 65350.0156 - val_loss: 4270624768.0000
# Epoch 61/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66039.5078 - loss: 4363227136.0000 - val_RootMeanSquaredError: 65305.1133 - val_loss: 4264757760.0000
# Epoch 62/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66169.9766 - loss: 4381529088.0000 - val_RootMeanSquaredError: 65278.9023 - val_loss: 4261335040.0000
# Epoch 63/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66225.0078 - loss: 4390426624.0000 - val_RootMeanSquaredError: 65253.9336 - val_loss: 4258075648.0000
# Epoch 64/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66620.5391 - loss: 4439639552.0000 - val_RootMeanSquaredError: 65256.2422 - val_loss: 4258376960.0000
# Epoch 65/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65792.2891 - loss: 4329537024.0000 - val_RootMeanSquaredError: 65268.7188 - val_loss: 4260005632.0000
# Epoch 66/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65541.1328 - loss: 4302114816.0000 - val_RootMeanSquaredError: 65230.9492 - val_loss: 4255076864.0000
# Epoch 67/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 65210.9531 - loss: 4253185536.0000 - val_RootMeanSquaredError: 65247.3203 - val_loss: 4257212928.0000
# Epoch 68/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 65148.3086 - loss: 4245394944.0000 - val_RootMeanSquaredError: 65226.7383 - val_loss: 4254527488.0000
# Epoch 69/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67393.3281 - loss: 4562187776.0000 - val_RootMeanSquaredError: 65245.1758 - val_loss: 4256933120.0000
# Epoch 70/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64878.3398 - loss: 4210103808.0000 - val_RootMeanSquaredError: 65189.0391 - val_loss: 4249611008.0000
# Epoch 71/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65020.6953 - loss: 4228516352.0000 - val_RootMeanSquaredError: 65153.7539 - val_loss: 4245011456.0000
# Epoch 72/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65987.4609 - loss: 4357707264.0000 - val_RootMeanSquaredError: 65149.0234 - val_loss: 4244395008.0000
# Epoch 73/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65665.0000 - loss: 4313327104.0000 - val_RootMeanSquaredError: 65126.7188 - val_loss: 4241489664.0000
# Epoch 74/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64876.8906 - loss: 4212291072.0000 - val_RootMeanSquaredError: 65123.2734 - val_loss: 4241040640.0000
# Epoch 75/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65579.8828 - loss: 4301735936.0000 - val_RootMeanSquaredError: 65122.9180 - val_loss: 4240994304.0000
# Epoch 76/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 66601.5156 - loss: 4438165504.0000 - val_RootMeanSquaredError: 65125.4844 - val_loss: 4241328640.0000
# Epoch 77/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 65579.6250 - loss: 4301650432.0000 - val_RootMeanSquaredError: 65110.9062 - val_loss: 4239429888.0000
# Epoch 78/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 65240.8438 - loss: 4257539584.0000 - val_RootMeanSquaredError: 65079.4766 - val_loss: 4235338496.0000
# Epoch 79/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 67569.1328 - loss: 4571590656.0000 - val_RootMeanSquaredError: 65114.2773 - val_loss: 4239869184.0000
# Epoch 80/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65120.8750 - loss: 4241675264.0000 - val_RootMeanSquaredError: 65114.0703 - val_loss: 4239842304.0000
# Epoch 81/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65698.6719 - loss: 4316742144.0000 - val_RootMeanSquaredError: 65061.8008 - val_loss: 4233037824.0000
# Epoch 82/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65239.9688 - loss: 4256676864.0000 - val_RootMeanSquaredError: 65042.0000 - val_loss: 4230461696.0000
# Epoch 83/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65646.8906 - loss: 4311108096.0000 - val_RootMeanSquaredError: 65007.5938 - val_loss: 4225987072.0000
# Epoch 84/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64493.6641 - loss: 4160953088.0000 - val_RootMeanSquaredError: 65020.4219 - val_loss: 4227655168.0000
# Epoch 85/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65105.5508 - loss: 4239805184.0000 - val_RootMeanSquaredError: 64995.6211 - val_loss: 4224430592.0000
# Epoch 86/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 67033.8203 - loss: 4504412160.0000 - val_RootMeanSquaredError: 64971.6172 - val_loss: 4221310976.0000
# Epoch 87/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64661.9023 - loss: 4184756992.0000 - val_RootMeanSquaredError: 65028.6523 - val_loss: 4228725504.0000
# Epoch 88/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 64782.2383 - loss: 4197825024.0000 - val_RootMeanSquaredError: 64954.9141 - val_loss: 4219140864.0000
# Epoch 89/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 64587.9844 - loss: 4173291008.0000 - val_RootMeanSquaredError: 64960.1094 - val_loss: 4219815936.0000
# Epoch 90/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 65005.4609 - loss: 4227681536.0000 - val_RootMeanSquaredError: 64930.9570 - val_loss: 4216028928.0000
# Epoch 91/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65870.4375 - loss: 4340219392.0000 - val_RootMeanSquaredError: 64884.1055 - val_loss: 4209947136.0000
# Epoch 92/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64092.5781 - loss: 4109559808.0000 - val_RootMeanSquaredError: 64896.1328 - val_loss: 4211508224.0000
# Epoch 93/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64978.2109 - loss: 4223783168.0000 - val_RootMeanSquaredError: 64900.4023 - val_loss: 4212062464.0000
# Epoch 94/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 66249.5703 - loss: 4390102016.0000 - val_RootMeanSquaredError: 64855.8008 - val_loss: 4206275072.0000
# Epoch 95/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 64996.7227 - loss: 4225225472.0000 - val_RootMeanSquaredError: 64873.8008 - val_loss: 4208610048.0000
# Epoch 96/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 65342.9141 - loss: 4272793600.0000 - val_RootMeanSquaredError: 64878.9844 - val_loss: 4209282560.0000
# Epoch 97/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65340.8945 - loss: 4276524800.0000 - val_RootMeanSquaredError: 64923.3906 - val_loss: 4215046400.0000
# Epoch 98/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65161.3516 - loss: 4247045888.0000 - val_RootMeanSquaredError: 64887.3438 - val_loss: 4210367488.0000
# Epoch 99/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 65208.3516 - loss: 4253410560.0000 - val_RootMeanSquaredError: 64872.7578 - val_loss: 4208474880.0000
# Epoch 100/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 64596.7109 - loss: 4173709312.0000 - val_RootMeanSquaredError: 64786.8633 - val_loss: 4197337600.0000

# %%
y_pred = sub_model.predict(X_test).reshape(y_test.shape[0])
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred[5:10], y_test[5:10]
# Out:
# (array([ 78357.8 , 293739.66, 248846.02, 246950.75, 162222.92],
#        dtype=float32),
#  array([ 65600., 344600., 235600., 233000., 192100.], dtype=float32))
