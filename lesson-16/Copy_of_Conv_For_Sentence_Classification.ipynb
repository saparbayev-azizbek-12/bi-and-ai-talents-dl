# %% [markdown]
# <a href="https://colab.research.google.com/github/saparbayev-azizbek-12/bi-and-ai-talents-dl/blob/main/lesson-16/Copy_of_Conv_For_Sentence_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sentence Classification Examples:
#
#     1. Sentiment Analysis
#         1.1 Positive
#         1.2 Negative
#         I really hate this music -> Negative -> 0
#         I love this food -> Positive -> 1
#     2. Jumla qaysi tilda yozilganini aniqlash
#     3. Names dataset classification

# %%
# %%capture
# !pip install unidecode

# %%
import torch
from google.colab import drive

drive.mount("/drive")
# Out:
# Mounted at /drive

# %%
from unidecode import unidecode

# %%
# !ls /drive/MyDrive/data/names
# Out:
# ls: cannot access '/drive/MyDrive/data/names': No such file or directory

# %%
# !cat /drive/MyDrive/data/names/Arabic.txt
# Out:
# cat: /drive/MyDrive/data/names/Arabic.txt: No such file or directory

# %%
import os
from glob import glob

# %%
root_dir = "/drive/MyDrive/names"
file_names = glob("*.txt", root_dir=root_dir)
unique_labels = sorted([os.path.splitext(file_name)[0] for file_name in file_names])
n_labels = len(unique_labels)

idx2label = {idx:label for idx, label in enumerate(unique_labels)}
label2idx = {label:idx for idx, label in idx2label.items()}

# %%
def replace(name, chars, target):
    for char in chars:
        name = name.replace(char, target)
    return name

# %%
X_names = []
Y_labels = []

for file_name in file_names:
    with open(os.path.join(root_dir, file_name), "rt", encoding='utf-8') as f:
        for line in f:
            name = line.strip().lower()
            name = unidecode(name)

            if name == 'to the first page':
                continue

            name = replace(name, [",", '1', "/b", ":", "\xa0"], '')
            name = replace(name, ['-'], ' ')

            X_names.append(name)
            Y_labels.append(os.path.splitext(file_name)[0])

# %% [markdown]
# 1. Remove "To The First Page" names from dataset
# 2. Replace ",", '1', "/B", ":", \xa0 with empty string
# 3. Replace '-' with ' '
# 4. Convert all the following from unicode to ascii:
# [ 'ß',
#  'à',
#  'á',
#  'ã',
#  'ä',
#  'ç',
#  'è',
#  'é',
#  'ê',
#  'ì',
#  'í',
#  'ñ',
#  'ò',
#  'ó',
#  'õ',
#  'ö',
#  'ù',
#  'ú',
#  'ü',
#  'ą',
#  'ł',
#  'ń',
#  'ś',
#  'ż']

# %%
pad_token = '.'
pad_token_id = 0

unique_chars = [pad_token] + sorted(set(''.join(X_names)))
idx2char = {idx:char for idx, char in enumerate(unique_chars)}
char2idx = {char:idx for idx, char in idx2char.items()}

def encode(name: str) -> list[int]:
    return [char2idx[char] for char in name]

def decode(ids: list[int]) -> str:
    return ''.join(idx2char[i] for i in ids)

# %%
Y = [label2idx[label] for label in Y_labels]
X = [encode(name) for name in X_names]

# %% [markdown]
# 1. Split data into train and test
# 2. NamesDataset for both train and test
# 3. Data Loader for both train and test with custom `collate` function

# %%
# 1. Split data into train and test
from sklearn.model_selection import train_test_split

X_train, Y_train, X_test, Y_test = train_test_split(
    X, Y, train_size=0.8, random_state=4, stratify=Y
)

# %%
# 2. NamesDataset for both train and test

import torch
from torch.utils.data import Dataset, DataLoader

class NamesDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return {
            "input_id": torch.tensor(self.X[idx]),
            "label": torch.tensor(self.Y[idx])
        }

train_dataset = NamesDataset(X_train, Y_train)
test_dataset = NamesDataset(X_test, Y_test)

# %%
# 3. Data Loader for both train and test with custom `collate` function
def collate(batch):
    print("working...")
    input_ids = [item['input_id'] for item in batch]
    labels = torch.stack([item['label'] for item in batch])

    max_len = max([len(input) for input in input_ids])
    print("Max len:", max_len)

    # Pad using pad_sequence function
    # input_ids_padded = torch.nn.utils.rnn.pad_sequence(input_ids, batch_first=True, padding_value=pad_token_id)

    # Pad manually
    input_ids_padded = []
    max_len = max(len(row) for row in batch)
    for row in batch:
        if len(row) < max_len:
          row += [pad_token_id]*(max_len-len(row))
          input_ids_padded.append(row)

        return {
            'input_ids': input_ids_padded,
            'labels': labels
        }

batch_size = 4

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate)
# Out:
# {'input_id': tensor([ 3,  4,  4, 20,  3,  5,  5, 11,  3,  4,  7, 16, 11]), 'label': tensor([ 4, 20,  3, 16,  6, 20, 11,  5, 13])}
# {'input_id': tensor([21, 22, 17, 20, 20]), 'label': tensor([ 5,  3, 15, 18, 17])}
# {'input_id': tensor([ 5, 20, 17, 25,  7]), 'label': tensor([21,  3, 15,  3, 10,  3])}
# {'input_id': tensor([ 9, 11, 21, 15, 17, 16,  6, 11]), 'label': tensor([22, 17, 23, 15,  3])}
# {'input_id': tensor([27,  3, 15,  4, 23, 20,  9]), 'label': tensor([10,  3, 14,  8, 17, 20,  6])}
# {'input_id': tensor([21, 11, 15, 17, 16, 11, 21]), 'label': tensor([21, 11,  3,  9, 27, 17])}
# {'input_id': tensor([ 3, 21,  8, 17, 23, 20]), 'label': tensor([10, 17, 20, 13, 11, 16])}
# {'input_id': tensor([27,  3, 16,  3, 14, 17, 24]), 'label': tensor([ 5, 10,  3, 15, 23, 21, 10,  7, 24])}
# {'input_id': tensor([ 5, 10,  7, 21, 10, 11, 20,  7]), 'label': tensor([21, 10, 11,  9,  3])}
# {'input_id': tensor([ 6, 27,  3, 13, 17, 24]), 'label': tensor([21,  3, 20, 20,  3,  8])}
# {'input_id': tensor([15,  3, 22, 21, 27, 23, 13]), 'label': tensor([20, 17, 13, 10, 11, 16])}
# {'input_id': tensor([20, 17, 21,  7, 16,  4, 14, 17, 17, 15]), 'label': tensor([16, 17, 21, 13, 11, 16])}
# {'input_id': tensor([25, 11, 14, 13,  7, 21]), 'label': tensor([20, 17, 15,  3])}
# {'input_id': tensor([15,  3, 14, 17, 16,  7]), 'label': tensor([ 6, 17, 17, 16])}
# {'input_id': tensor([ 4,  3, 13, 20, 27, 15, 17, 24]), 'label': tensor([10,  3, 11, 13, 17, 24])}
# {'input_id': tensor([13,  3, 22, 28,  7, 24, 15,  3, 16]), 'label': tensor([17, 14,  6, 10,  3, 15])}
# {'input_id': tensor([18,  3, 16, 13, 10, 23, 20, 21, 22]), 'label': tensor([ 3, 24, 10, 11, 15, 17, 24, 11, 22,  5, 10])}
# {'input_id': tensor([ 4,  3, 13, 11, 16, 17, 24]), 'label': tensor([22, 21,  7, 16, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([27,  3, 10, 11, 15, 17, 24, 11,  5, 10]), 'label': tensor([ 8, 11, 16, 22, 11, 13, 22, 11, 13, 17, 24])}
# {'input_id': tensor([20, 23, 22, 22,  7, 20]), 'label': tensor([ 3, 25,  7, 20, 22,  5, 10,  7, 16, 13, 17])}
# {'input_id': tensor([ 9,  7, 20,  9,  7, 21]), 'label': tensor([12,  3, 22, 21, 13, 17, 24])}
# {'input_id': tensor([22, 20, 11, 16, 10]), 'label': tensor([15,  3, 21, 11, 10])}
# {'input_id': tensor([11, 21, 13, 20,  3]), 'label': tensor([13,  3,  5, 10,  3,  7, 24])}
# {'input_id': tensor([27, 23,  9,  3, 11]), 'label': tensor([13,  3, 14,  3, 13, 17, 21])}
# {'input_id': tensor([24, 17, 11,  9, 22]), 'label': tensor([16,  3, 21, 21,  3, 20])}
# {'input_id': tensor([ 9, 25,  7, 20,  6,  7, 20]), 'label': tensor([10, 23, 16, 17, 24])}
# {'input_id': tensor([18,  3, 22, 21, 27, 16,  3]), 'label': tensor([11, 21, 10, 11, 15, 23, 20,  3])}
# {'input_id': tensor([ 4,  3,  4,  3,  6, 12,  3, 16, 17, 24]), 'label': tensor([ 4,  3, 21, 22, 20, 27,  9, 11, 16])}
# {'input_id': tensor([ 3, 16,  6, 20,  7, 25]), 'label': tensor([14,  7, 17, 16,  7, 16, 13, 17])}
# {'input_id': tensor([ 8, 17, 23, 20,  3, 13, 11, 21]), 'label': tensor([27, 23, 13, 10, 16, 17])}
# {'input_id': tensor([24,  3, 12, 17, 20, 17, 24]), 'label': tensor([ 3,  4,  3, 14, 11, 13, 10, 11, 16])}
# {'input_id': tensor([ 7, 14,  3, 22, 17, 16, 22, 21,  7, 24]), 'label': tensor([21,  5, 10,  7, 18,  7, 14,  7, 24])}
# {'input_id': tensor([ 7, 15,  7, 14, 11, 16]), 'label': tensor([ 9, 20,  3, 10,  3, 15])}
# {'input_id': tensor([12, 23, 16]), 'label': tensor([21,  3, 14, 11,  4])}
# {'input_id': tensor([18, 11, 21, 13, 17, 22, 11, 16]), 'label': tensor([ 9, 14,  7, 16, 16])}
# {'input_id': tensor([15, 17, 16, 22,  3,  9, 16,  7]), 'label': tensor([17, 22,  3, 13,  3])}
# {'input_id': tensor([ 8,  3, 21, 10, 11, 16,  9,  4,  3, 23,  7, 20]), 'label': tensor([ 3, 25,  3,  6])}
# {'input_id': tensor([ 7, 24, 21, 22,  3,  8, 11,  7, 24]), 'label': tensor([18, 20,  3, 22, 22])}
# {'input_id': tensor([15, 17, 16, 22,  7, 20, 17]), 'label': tensor([26, 27, 14,  3, 16,  6,  7, 20])}
# {'input_id': tensor([12,  3, 13, 23,  4, 11, 13]), 'label': tensor([ 4,  7, 13, 17, 24, 11,  5, 10,  1,  5, 10,  7, 20, 13,  3, 21, 21, 13,
#         27])}
# {'input_id': tensor([ 3,  4,  4,  3, 21,  5, 11,  3]), 'label': tensor([15, 23, 16, 21, 22,  7, 20])}
# {'input_id': tensor([20, 17, 22,  7, 16,  4,  7, 20,  9]), 'label': tensor([ 8, 17, 22, 11, 16, 17, 24])}
# {'input_id': tensor([ 4,  7, 14, 17, 10, 11, 16]), 'label': tensor([ 4,  7, 28, 23,  9, 14, 27])}
# {'input_id': tensor([22, 23, 20, 23, 21, 10,  7, 24]), 'label': tensor([15, 11, 16, 13, 17, 24, 11,  5, 10])}
# {'input_id': tensor([24,  3, 21, 27,  3, 16, 17, 24, 11,  5, 10]), 'label': tensor([22, 17, 25,  7, 20, 21])}
# {'input_id': tensor([14, 11, 16, 24, 11, 14, 14,  7]), 'label': tensor([10, 17,  4, 21, 17, 16])}
# {'input_id': tensor([16,  3, 11,  8,  7, 10]), 'label': tensor([12,  7, 14, 23,  6,  7, 24])}
# {'input_id': tensor([ 4, 17, 16, 16,  7, 22]), 'label': tensor([22,  3, 13,  3, 15, 23, 20,  3])}
# {'input_id': tensor([25, 10, 11, 22, 14, 17,  5, 13]), 'label': tensor([25,  7, 11,  5, 10,  7, 20, 22])}
# {'input_id': tensor([14,  7, 16, 16, 17, 16]), 'label': tensor([ 8, 11, 22, 28, 21, 11, 15, 15, 17, 16, 21])}
# {'input_id': tensor([14, 17, 22, 22,  7, 20]), 'label': tensor([ 8, 20,  3, 16, 13])}
# {'input_id': tensor([14, 17, 20, 11, 21]), 'label': tensor([10, 27,  3, 22,  3])}
# {'input_id': tensor([21, 22,  3, 24, 20, 17, 18, 17, 23, 14, 17, 21]), 'label': tensor([21, 18,  7, 16,  5,  7])}
# {'input_id': tensor([20,  3, 13, 10,  3, 14, 21, 13, 27]), 'label': tensor([ 9, 23, 14, 27,  9,  3])}
# {'input_id': tensor([ 3, 24,  3, 13, 17,  8,  8]), 'label': tensor([22, 23,  4, 17, 14, 22, 21,  7, 24])}
# {'input_id': tensor([ 4, 14,  3, 11, 20]), 'label': tensor([ 4,  7, 20,  9,  7, 20])}
# {'input_id': tensor([19, 23, 20,  7, 21, 10, 11]), 'label': tensor([28, 17,  9,  4, 27])}
# {'input_id': tensor([28, 11, 21]), 'label': tensor([ 4,  7, 16, 16,  7, 22, 22])}
# {'input_id': tensor([ 9,  7, 20,  3,  5, 11, 15, 17, 21]), 'label': tensor([24,  7, 14, 11, 13, 27])}
# {'input_id': tensor([ 7, 24, 21, 11, 23, 13, 17, 24]), 'label': tensor([ 6, 23,  6, 14,  7, 27])}
# {'input_id': tensor([23, 21, 22, 11, 16,  5, 10,  7, 16, 13, 17]), 'label': tensor([13, 20,  7, 27, 14, 11, 16,  9])}
# {'input_id': tensor([22,  7, 22,  7, 20, 11,  5, 10,  7, 24]), 'label': tensor([10, 23, 20,  3, 16, 17, 24])}
# {'input_id': tensor([12,  3, 15, 14, 11, 13, 10,  3, 16, 17, 24]), 'label': tensor([20,  7, 15,  7, 28])}
# {'input_id': tensor([27, 17, 21, 10, 11,  8, 23, 15, 11]), 'label': tensor([ 4,  3, 13, 21, 10, 22,  3, 16, 17, 24, 21, 13, 11])}
# {'input_id': tensor([21,  7, 11,  8]), 'label': tensor([21, 20, 17, 23, 20])}
# {'input_id': tensor([22, 20,  7, 16, 16,  7, 20, 27]), 'label': tensor([12,  7, 21, 22, 13, 17, 24])}
# {'input_id': tensor([ 3,  4,  3, 16, 11, 16]), 'label': tensor([ 9, 20,  3, 16,  6,  4,  7, 20,  9])}
# {'input_id': tensor([ 3,  4,  6, 23, 14, 13,  3,  6, 27, 20, 17,  8,  8]), 'label': tensor([28, 10,  7, 14,  7, 28, 13, 17])}
# {'input_id': tensor([25,  3, 14, 18, 17, 14,  7]), 'label': tensor([20,  3, 15,  7,  5, 13,  7, 20])}
# {'input_id': tensor([15,  3, 10, 11, 16]), 'label': tensor([ 9, 20, 23, 21, 10,  7, 16, 13, 17])}
# {'input_id': tensor([16,  7, 21, 13, 20,  7,  4, 11, 16]), 'label': tensor([15, 11, 10,  3, 14,  5, 10,  7, 16, 13, 17])}
# {'input_id': tensor([24, 11, 16, 11, 23, 21]), 'label': tensor([ 5, 20, 17, 25, 16])}
# {'input_id': tensor([16, 17, 20, 15]), 'label': tensor([20,  3,  6,  7, 15,  3,  5, 10,  7, 20])}
# {'input_id': tensor([17, 16, 11, 13, 17, 24]), 'label': tensor([15,  3, 13, 11, 16])}
# {'input_id': tensor([ 4,  3, 14,  3,  4,  3, 11]), 'label': tensor([ 9, 23,  6, 11, 14, 11, 16])}
# {'input_id': tensor([18,  3, 22, 20, 11,  5, 13]), 'label': tensor([10,  3, 11, 20, 23, 22,  6, 11, 16, 17, 24])}
# {'input_id': tensor([20, 23, 28, 10, 11, 14, 17]), 'label': tensor([21, 10,  7, 20, 25, 17, 17,  6])}
# {'input_id': tensor([18,  7,  5, 13]), 'label': tensor([15,  3, 14, 17, 17,  8])}
# {'input_id': tensor([16,  3, 18, 17, 14,  7, 17, 16, 11]), 'label': tensor([22, 21, 23, 20, 23, 27,  3])}
# {'input_id': tensor([22, 21, 23, 15, 23, 20,  3]), 'label': tensor([22, 17, 15, 17, 20, 11])}
# {'input_id': tensor([22, 21, 17,  9,  3, 21]), 'label': tensor([ 4,  3,  5, 10, 27,  3, 16, 21, 13,  3, 21])}
# {'input_id': tensor([ 4, 17, 22, 20, 17, 21]), 'label': tensor([15,  3, 20, 22, 27, 16, 27, 23, 13])}
# {'input_id': tensor([ 4,  3, 14,  3, 13, 10, 17, 25, 21, 13, 11]), 'label': tensor([16,  3, 11,  8,  7, 10])}
# {'input_id': tensor([ 5, 17, 17, 15,  4,  7, 21]), 'label': tensor([28, 17,  9,  4, 27])}
# {'input_id': tensor([ 7, 24, 21, 27, 23, 22, 11, 16]), 'label': tensor([15, 11, 14, 14, 25,  3, 20,  6])}
# {'input_id': tensor([26, 11, 16,  9]), 'label': tensor([23, 28, 10, 24,  3])}
# {'input_id': tensor([24, 14,  3, 21,  7, 13]), 'label': tensor([24,  3, 21, 21, 11, 14, 11, 13, 17, 21])}
# {'input_id': tensor([22,  5, 10,  7, 13, 17, 15,  3, 21, 17, 24]), 'label': tensor([12, 23,  3, 20,  7, 28])}
# {'input_id': tensor([ 9,  3, 14, 14, 27,  3, 15, 17, 24]), 'label': tensor([28, 10, 23, 14,  7, 24])}
# {'input_id': tensor([18, 11, 20, 23, 28, 27,  3, 16]), 'label': tensor([ 5, 23, 15, 15, 11, 16,  9])}
# {'input_id': tensor([ 3,  9,  3, 11,  9,  7, 14,  6, 11,  7, 24]), 'label': tensor([23, 22, 20, 17,  4, 11, 16])}
# {'input_id': tensor([7, 6, 9, 7]), 'label': tensor([ 5,  3, 20,  4, 17, 16, 11])}
# {'input_id': tensor([15,  3, 22, 21, 13,  7, 24, 11,  5, 10]), 'label': tensor([22,  3, 27, 14, 17, 20])}
# {'input_id': tensor([18, 20, 27, 17, 20]), 'label': tensor([ 9, 20,  3, 16, 17, 24])}
# {'input_id': tensor([24, 11,  5, 13,  7, 20, 15,  3, 16]), 'label': tensor([15, 11, 27,  3,  9, 11])}
# {'input_id': tensor([ 6, 17, 25, 16, 11,  7]), 'label': tensor([ 5,  3, 15,  7, 20, 17, 16])}
# {'input_id': tensor([12, 23, 18,  3, 16,  7, 16, 13, 17]), 'label': tensor([13,  7, 16, 28,  7, 14])}
# {'input_id': tensor([25, 11, 14, 21, 17, 16]), 'label': tensor([18, 11, 20, 17, 28, 10, 13, 17, 24])}
# {'input_id': tensor([13, 11,  6,  6, 14,  7]), 'label': tensor([22,  3, 14, 27,  3, 16, 22, 21,  7, 24])}
# {'input_id': tensor([ 9, 20,  3, 15,  4,  7, 20,  9]), 'label': tensor([15, 17, 13,  7,  7, 24])}
# {'input_id': tensor([ 6, 20, 23, 15, 15, 17, 16,  6]), 'label': tensor([ 4, 23,  5, 13])}
# {'input_id': tensor([11, 21,  3,  3, 13, 11,  6, 11, 21]), 'label': tensor([14,  7,  5,  5,  7])}
# {'input_id': tensor([18,  7, 14,  7,  7, 24]), 'label': tensor([ 7, 14, 14,  7, 20,  3, 27])}
# {'input_id': tensor([ 4,  7, 16,  7, 16,  3, 22, 11]), 'label': tensor([18,  3, 18, 18])}
# {'input_id': tensor([24, 11, 21, 16,  3, 18, 23]), 'label': tensor([ 8,  3, 25, 16])}
# {'input_id': tensor([ 6,  3,  9,  3,  7, 24]), 'label': tensor([15, 17,  9, 10,  3,  6,  3, 15])}
# {'input_id': tensor([13, 11, 15,  4, 14,  7]), 'label': tensor([24,  7, 20,  4, 11, 22, 21, 13, 27])}
# {'input_id': tensor([22,  7, 20,  3,  6,  3]), 'label': tensor([22,  7, 15, 18, 14,  3, 20])}
# {'input_id': tensor([ 5, 10,  7, 18, 23, 20,  7, 16, 13, 17]), 'label': tensor([28, 10, 23, 20,  3, 24,  7, 14])}
# {'input_id': tensor([25,  3, 23,  9, 10]), 'label': tensor([13,  3, 14, 11, 16, 17, 24, 11,  5, 10])}
# {'input_id': tensor([10,  3,  6,  3, 20, 22, 21,  7, 24]), 'label': tensor([ 4,  3, 10, 21, 10, 11,  7, 24])}
# {'input_id': tensor([28, 10, 24,  3, 16,  7, 22, 21, 13, 27]), 'label': tensor([21, 10,  3, 15, 15,  3, 21])}
# {'input_id': tensor([10,  3, 23, 21, 14,  7, 20]), 'label': tensor([ 4,  3,  4,  3,  6, 12,  3, 16])}
# {'input_id': tensor([28, 10,  3, 22, 13, 17, 24]), 'label': tensor([21, 10,  3, 20, 13,  7, 27])}
# {'input_id': tensor([21, 23,  4,  7, 20, 22, 17, 24,  3]), 'label': tensor([21,  5, 10,  7, 18,  3, 16, 21, 13, 27])}
# {'input_id': tensor([ 5, 14, 17, 21,  7]), 'label': tensor([ 8, 20, 17, 21, 22, 11,  5, 13])}
# {'input_id': tensor([16, 17, 20, 15,  3, 16]), 'label': tensor([17, 22, 17, 15, 17])}
# {'input_id': tensor([28, 10, 11, 24, 17, 24]), 'label': tensor([15,  3, 20, 13, 21])}
# {'input_id': tensor([ 5, 10, 20, 27, 21,  3, 16, 22, 10, 17, 18, 17, 23, 14, 17, 21]), 'label': tensor([25,  3, 21,  7, 15])}
# {'input_id': tensor([22, 11, 15, 11, 16]), 'label': tensor([10,  3, 14, 27,  3, 18, 11, 16])}
# {'input_id': tensor([ 3, 20, 16,  7, 22, 22]), 'label': tensor([17,  4, 17, 20, 11, 16])}
# {'input_id': tensor([24, 17, 28, 16,  7, 21,  7, 16, 21, 13, 27]), 'label': tensor([ 5,  3, 20,  6, 17, 16,  3])}
# {'input_id': tensor([22, 23, 15,  3]), 'label': tensor([ 6,  2,  5, 20, 23, 28,  7])}
# {'input_id': tensor([12,  7, 15, 21]), 'label': tensor([ 4, 17, 22, 20, 17, 21])}
# {'input_id': tensor([28, 10, 11, 22,  3, 20,  7, 24]), 'label': tensor([15, 11, 27, 17, 21, 10, 11])}
# {'input_id': tensor([ 3, 14, 24,  3, 20,  7, 28]), 'label': tensor([24,  3, 14,  6,  3,  7, 24])}
# {'input_id': tensor([21,  5, 10,  7, 18, 17, 22, 27,  7, 24]), 'label': tensor([13, 10, 17, 23, 20, 27])}
# {'input_id': tensor([ 9,  3,  8, 22]), 'label': tensor([20, 23, 21, 21, 17, 16])}
# {'input_id': tensor([14, 11, 16,  7, 21]), 'label': tensor([20,  3, 16,  3])}
# {'input_id': tensor([13, 17, 14, 22]), 'label': tensor([24,  3, 14,  7, 16, 22,  7, 11])}
# {'input_id': tensor([18, 11,  7, 20, 16, 17]), 'label': tensor([ 3, 22, 11, 27,  7, 10])}
# {'input_id': tensor([17,  2, 10,  3, 14, 14, 17, 20,  3, 16]), 'label': tensor([21,  3,  8,  3, 20])}
# {'input_id': tensor([22, 21, 27, 23, 20, 23, 18,  3]), 'label': tensor([20,  7,  3,  6,  7, 20])}
# {'input_id': tensor([15, 11, 21,  5, 10,  7, 16, 13, 17]), 'label': tensor([12,  3, 13, 23, 21, 10])}
# {'input_id': tensor([15, 17, 16,  3,  9, 10,  3, 16]), 'label': tensor([ 4,  3,  6, 11, 13, 17, 24])}
# {'input_id': tensor([25, 11, 20, 22, 10]), 'label': tensor([10, 17, 21, 10, 11, 16, 17])}
# {'input_id': tensor([ 3, 14,  7, 21,  4, 23, 20, 27]), 'label': tensor([16,  7, 14, 27, 23,  4, 11, 16])}
# {'input_id': tensor([15,  3, 10, 14,  3, 11]), 'label': tensor([ 6, 17,  6, 21, 17, 16])}
# {'input_id': tensor([ 6, 28, 10,  7, 14,  7, 18, 17, 24]), 'label': tensor([13, 17, 23,  4,  3])}
# {'input_id': tensor([20,  3, 16,  9]), 'label': tensor([ 4,  3,  4,  3, 13, 10,  3, 16, 17,  8,  8])}
# {'input_id': tensor([12, 11, 24, 17, 22, 11, 16, 21, 13, 27]), 'label': tensor([14, 11, 15, 17, 21, 10, 11, 16])}
# {'input_id': tensor([11, 21,  3]), 'label': tensor([ 7, 16, 17, 10, 11, 16])}
# {'input_id': tensor([ 4,  7, 14, 17, 21, 24,  7, 22]), 'label': tensor([13,  7,  3, 14])}
# {'input_id': tensor([12, 11,  9, 23, 14, 21, 13, 27]), 'label': tensor([12, 23, 10, 16, 11, 16])}
# {'input_id': tensor([ 4,  7, 14, 17, 21, 10,  3, 18, 13, 17, 24]), 'label': tensor([14,  7, 11, 22, 28])}
# {'input_id': tensor([25, 10,  7, 14,  3, 16]), 'label': tensor([18,  7, 22,  7, 20])}
# {'input_id': tensor([10,  3, 11, 13]), 'label': tensor([18, 20, 11,  7, 15, 27, 10, 17, 24])}
# {'input_id': tensor([28, 10, 11,  6, 13, 17, 24]), 'label': tensor([ 6, 11, 18, 18,  7, 20])}
# {'input_id': tensor([ 3, 24, 11, 16, 17, 24, 11, 22, 21, 13, 27]), 'label': tensor([22, 17, 20, 11, 21,  7, 11])}
# {'input_id': tensor([14, 11,  5, 10, 22,  7, 16,  4,  7, 20,  9]), 'label': tensor([17, 15,  7,  9, 17, 24])}
# {'input_id': tensor([22, 17, 15,  3, 16,  7, 13]), 'label': tensor([ 9, 14, 23, 10, 17, 22, 13, 17])}
# {'input_id': tensor([10,  3, 14,  7, 24, 11, 16, 21, 13, 27]), 'label': tensor([10, 17, 20, 17, 21, 10, 11, 14, 22, 21,  7, 24])}
# {'input_id': tensor([ 9,  7, 22, 27,  3]), 'label': tensor([ 6, 20, 17, 12, 12, 11, 16])}
# {'input_id': tensor([21, 10,  3, 10,  4,  3, 28, 17, 24]), 'label': tensor([27,  3, 13, 23, 22, 13, 11, 16])}
# {'input_id': tensor([14, 11,  5, 10, 13, 17]), 'label': tensor([ 8, 17, 20, 22, 17, 24])}
# {'input_id': tensor([12, 14, 23, 13, 22, 17, 24]), 'label': tensor([17, 14, 11, 24,  7, 20])}
# {'input_id': tensor([ 6, 11, 13, 17, 24,  7, 16, 13, 17]), 'label': tensor([10,  3,  6, 17, 16, 17, 24])}
# {'input_id': tensor([13, 14,  7, 20, 13,  7, 16]), 'label': tensor([ 3,  4,  6, 23, 14, 14,  3,  6, 28, 10,  3, 16, 17,  8,  8])}
# {'input_id': tensor([15,  3, 20, 22, 11, 16]), 'label': tensor([12, 11, 24, 13, 17, 24, 11,  5, 10])}
# {'input_id': tensor([20, 17,  4,  7, 20, 22]), 'label': tensor([20,  3, 11, 10,  7, 14, 21, 17, 16])}
# {'input_id': tensor([17, 22, 21, 23, 13,  3]), 'label': tensor([ 4,  3, 25,  3, 20, 11, 16])}
# {'input_id': tensor([25,  3, 22,  3, 16,  3,  4,  7]), 'label': tensor([21, 16, 11,  7,  9, 17, 25, 21, 13, 11])}
# {'input_id': tensor([22,  3, 27,  3, 15,  3]), 'label': tensor([ 5, 10,  3, 15])}
# {'input_id': tensor([12, 11,  9, 11, 16]), 'label': tensor([15, 11, 10,  3, 14, 23, 21, 10, 13, 11, 16])}
# {'input_id': tensor([15, 17, 20,  5, 17, 21]), 'label': tensor([ 4, 14,  7,  5, 10,  3])}
# {'input_id': tensor([15,  3, 22,  3, 21, 17, 24]), 'label': tensor([22,  3, 21, 21, 11, 17,  9, 14, 17, 23])}
# {'input_id': tensor([21,  3, 11, 22,  3, 16, 17, 24]), 'label': tensor([ 8,  7, 20, 20,  7, 11, 20, 17])}
# {'input_id': tensor([22, 23, 20, 15,  3, 16, 17, 24]), 'label': tensor([11, 21, 21,  3])}
# {'input_id': tensor([ 4,  3, 23, 22, 11, 21, 22,  3]), 'label': tensor([20,  7, 16, 17, 24])}
# {'input_id': tensor([11, 15,  3, 22, 13, 23, 14, 17, 24]), 'label': tensor([10, 23, 20, 14,  7, 27])}
# {'input_id': tensor([15, 11,  8, 21, 23,  6]), 'label': tensor([28, 10, 15, 11, 16, 13, 17])}
# {'input_id': tensor([28,  3, 15, 17, 20,  3, 16, 17]), 'label': tensor([ 4,  3, 24,  3, 20, 11, 16])}
# {'input_id': tensor([18,  7, 22, 20,  3, 13, 11, 21]), 'label': tensor([ 5, 10,  3,  9,  3, 16, 17, 24])}
# {'input_id': tensor([19, 23, 20,  3, 11, 21, 10, 11]), 'label': tensor([ 4,  7, 14, 21, 10, 22,  7, 11, 16])}
# {'input_id': tensor([15,  3, 22, 21,  3,  7, 24]), 'label': tensor([22, 23,  4, 14, 11])}
# {'input_id': tensor([12, 14, 17,  4,  3]), 'label': tensor([22, 28,  3,  9, 23, 16, 17, 24])}
# {'input_id': tensor([ 8,  3, 11, 20,  4, 20,  3,  5,  7]), 'label': tensor([11,  9,  9, 14,  7,  6,  7, 16])}
# {'input_id': tensor([ 5,  3, 16, 16]), 'label': tensor([27,  7, 18, 11, 21, 10,  7, 24])}
# {'input_id': tensor([27, 23, 28, 10,  3, 13, 17, 24]), 'label': tensor([11,  6,  6, 17, 16])}
# {'input_id': tensor([22, 21, 11, 17, 14, 13, 17, 24, 21, 13, 27]), 'label': tensor([ 9, 20, 17, 21])}
# {'input_id': tensor([ 3, 15,  3, 20, 11]), 'label': tensor([16, 17, 10])}
# {'input_id': tensor([10, 11, 20,  3, 17, 13,  3]), 'label': tensor([27,  3,  4, 23, 20, 17, 24])}
# {'input_id': tensor([ 5, 17, 18,  7, 14,  3, 16,  6]), 'label': tensor([ 4, 20,  3,  6, 27])}
# {'input_id': tensor([ 3,  9, 20,  3, 16, 17, 25, 21, 13, 27]), 'label': tensor([ 4,  3, 14, 14,  3, 16, 22, 27, 16,  7])}
# {'input_id': tensor([ 4,  3,  5, 10, 11, 16, 21, 13, 11]), 'label': tensor([ 4,  3, 11,  6, 23, 13, 17,  8,  8])}
# {'input_id': tensor([19, 23, 20,  3, 11, 21, 10, 11]), 'label': tensor([ 9, 20, 23, 21, 10, 11])}
# {'input_id': tensor([10, 23,  6, 17, 13, 17, 20, 15, 17, 24]), 'label': tensor([15,  3, 20, 21, 28,  3, 14,  7, 13])}
# {'input_id': tensor([12,  3,  4, 20,  7, 24]), 'label': tensor([ 5, 10,  7, 16,  9])}
# {'input_id': tensor([10, 23, 17]), 'label': tensor([ 3, 25,  7, 20,  4,  3, 10])}
# {'input_id': tensor([ 4,  3, 11]), 'label': tensor([21,  7, 11,  8])}
# {'input_id': tensor([15,  3, 16, 21, 17, 23, 20]), 'label': tensor([ 6,  3, 15, 10,  3, 16])}
# {'input_id': tensor([ 6, 28, 10,  3, 16,  3, 21, 10, 11, 27,  3]), 'label': tensor([ 3,  4, 20,  3, 15, 13, 17,  8,  8])}
# {'input_id': tensor([ 7, 14,  6,  7, 21, 22, 17, 16]), 'label': tensor([13,  3, 28, 23, 27, 17, 21, 10, 11])}
# {'input_id': tensor([ 4, 17, 21,  5, 10]), 'label': tensor([22, 21,  7, 10,  3, 16, 21, 13, 27])}
# {'input_id': tensor([15, 17, 20,  5, 17, 21]), 'label': tensor([22,  3, 20, 20])}
# {'input_id': tensor([15,  5, 15,  3, 10, 17, 16]), 'label': tensor([ 4,  3,  6, 17, 24])}
# {'input_id': tensor([13,  3, 15, 11, 17, 13,  3]), 'label': tensor([ 4,  3, 28, 27, 14, 16, 11, 13, 17, 24])}
# {'input_id': tensor([10, 11, 22, 20, 11, 16]), 'label': tensor([22, 17, 21, 10, 11, 21, 10,  3, 11])}
# {'input_id': tensor([23, 10,  3,  4, 11, 16]), 'label': tensor([15, 17, 20,  7, 22, 22, 11])}
# {'input_id': tensor([27,  3, 22,  7, 21]), 'label': tensor([15, 11,  8, 21, 23,  6])}
# {'input_id': tensor([17, 14,  6, 11, 16,  9]), 'label': tensor([ 3, 27, 22, 17, 16])}
# {'input_id': tensor([21,  3, 25,  3, 15, 23, 20,  3]), 'label': tensor([ 8, 17, 21, 21])}
# {'input_id': tensor([ 3, 15,  3, 20, 11]), 'label': tensor([14,  3, 16,  9])}
# {'input_id': tensor([18,  7,  7, 20, 21]), 'label': tensor([24,  7, 14,  3])}
# {'input_id': tensor([28, 10, 23, 13, 17, 24]), 'label': tensor([21, 11, 15, 17, 16, 21])}
# {'input_id': tensor([20,  3, 10, 15,  3, 16, 11, 16, 17, 24]), 'label': tensor([21,  3, 27,  7,  9, 10])}
# {'input_id': tensor([21, 10,  3, 11, 13, 10, 23, 22,  6, 11, 16, 17, 24]), 'label': tensor([21, 20, 17, 23, 20])}
# {'input_id': tensor([12, 17, 20,  6,  3, 16]), 'label': tensor([17,  6, 17, 16, 17,  9, 10, 23,  7])}
# {'input_id': tensor([15, 23, 28, 11, 18, 17, 24]), 'label': tensor([24,  3, 14, 27,  3, 16, 17, 24])}
# {'input_id': tensor([12,  3, 16,  9,  3, 20,  4,  7, 20]), 'label': tensor([15, 23, 14,  6,  3, 21, 10,  7, 24])}
# {'input_id': tensor([ 3,  9,  3, 22, 27,  7, 24]), 'label': tensor([24,  3, 14,  7, 24, 21, 13, 27])}
# {'input_id': tensor([ 9,  3,  4,  7, 20]), 'label': tensor([13, 17, 28,  3])}
# {'input_id': tensor([15,  3,  3, 21]), 'label': tensor([16,  3, 13,  3, 22,  3])}
# {'input_id': tensor([22, 21, 23, 16, 17,  6,  3]), 'label': tensor([21, 17, 15, 15,  7, 20])}
# {'input_id': tensor([21, 22, 17, 20,  7, 27]), 'label': tensor([10, 11, 14, 13, 17, 24])}
# {'input_id': tensor([21,  3, 14, 23,  5,  5, 11]), 'label': tensor([ 4,  7, 14, 14])}
# {'input_id': tensor([ 3,  4, 20,  3, 13, 10, 11, 15, 17, 24]), 'label': tensor([20, 11,  5,  5, 10,  7, 22, 22, 11])}
# {'input_id': tensor([ 6, 17,  4,  4, 11, 16]), 'label': tensor([22, 17, 23, 15,  3])}
# {'input_id': tensor([24, 27,  3, 13, 10, 11, 20,  7, 24]), 'label': tensor([13, 20,  7, 15, 14,  3,  5,  7, 13])}
# {'input_id': tensor([28, 10,  3, 14, 27,  4, 11, 16]), 'label': tensor([ 9,  3, 14, 14])}
# {'input_id': tensor([ 9, 14,  3, 24,  5, 10,  7, 24]), 'label': tensor([ 3,  4, 20,  3, 15, 17, 25, 11,  5, 10])}
# {'input_id': tensor([15, 11, 10,  3, 11, 14, 27, 23, 13]), 'label': tensor([ 5,  7,  3, 14, 14,  3,  5, 10])}
# {'input_id': tensor([ 3,  4,  3,  6, 11]), 'label': tensor([15, 17, 24,  5, 10, 23, 16])}
# {'input_id': tensor([13,  3, 21, 21,  3,  4]), 'label': tensor([ 4,  3, 13, 10, 22,  5, 10, 11, 24,  3, 16,  6, 28, 10, 11])}
# {'input_id': tensor([ 3, 15,  3,  6,  7, 11]), 'label': tensor([20,  7,  6,  6, 27])}
# {'input_id': tensor([22, 23, 20, 11, 21,  5, 10,  7, 24]), 'label': tensor([ 3,  6, 11,  9,  3, 15, 17, 24])}
# {'input_id': tensor([ 3,  4,  4,  7, 27]), 'label': tensor([15,  5,  5,  3, 14, 14, 23, 15])}
# {'input_id': tensor([22, 11, 15, 11, 20, 27,  3, 28,  7, 24]), 'label': tensor([28,  6, 23, 16, 17, 25, 21, 13, 11])}
# {'input_id': tensor([13,  3, 22,  3, 27,  3, 16,  3,  9, 11]), 'label': tensor([20, 17, 21,  7, 16,  4,  7, 20,  9,  7, 20])}
# {'input_id': tensor([28, 10,  3, 17]), 'label': tensor([14,  7, 16, 28])}
# {'input_id': tensor([12,  3, 16, 21]), 'label': tensor([23, 21, 22, 11, 16, 13, 11, 16])}
# {'input_id': tensor([ 4,  3,  4,  3, 13]), 'label': tensor([10,  3, 16,  7, 24, 11,  5, 10])}
# {'input_id': tensor([10,  3, 14,  3,  4, 11]), 'label': tensor([24, 14,  3, 10, 17, 21])}
# {'input_id': tensor([ 9,  3,  4,  7, 20]), 'label': tensor([13, 23, 16, 22, 28])}
# {'input_id': tensor([15,  3, 13, 21, 11, 15, 17, 24, 21, 13, 27]), 'label': tensor([13,  3, 22, 21, 23, 20,  3])}
# {'input_id': tensor([ 4,  3, 13,  3, 16, 17, 24]), 'label': tensor([21,  3, 15, 21, 17, 16])}
# {'input_id': tensor([ 5, 14,  7,  3, 20, 27]), 'label': tensor([ 3, 16, 22, 17, 16,  7, 14, 14, 11])}
# {'input_id': tensor([18, 20, 11, 24,  3, 14, 11, 13, 10, 11, 16]), 'label': tensor([28, 10,  7, 14,  7, 28, 16, 11, 13, 17, 24])}
# {'input_id': tensor([21,  5, 10, 17, 17, 16,  7, 16,  4, 23, 20,  9]), 'label': tensor([25,  7,  3, 24,  7, 20])}
# {'input_id': tensor([21,  3,  4,  4,  3,  9]), 'label': tensor([20, 17, 10, 14, 11, 16])}
# {'input_id': tensor([15, 17, 20,  7, 22, 17, 16]), 'label': tensor([13,  3, 20, 22, 23, 28, 17, 24])}
# {'input_id': tensor([14,  3, 23]), 'label': tensor([ 5, 10, 11, 13,  3, 16, 17, 24])}
# {'input_id': tensor([13,  3, 21, 21, 11, 21]), 'label': tensor([ 6,  7, 20, 11,  9, 14,  3, 28, 17, 24])}
# {'input_id': tensor([11, 21, 10, 11, 27,  3, 15,  3]), 'label': tensor([18,  3, 28, 23, 13, 10, 11, 16])}
# {'input_id': tensor([21,  5, 10,  7, 18, 13, 11, 16]), 'label': tensor([22, 11, 14, 14,  7, 22, 22])}
# {'input_id': tensor([ 9, 17, 13]), 'label': tensor([ 6,  7, 21, 27,  3, 22, 21, 13, 17, 24])}
# {'input_id': tensor([24, 27,  3, 28, 15, 11, 13, 11, 16]), 'label': tensor([ 9, 17, 16, 28,  3, 14,  7, 28])}
# {'input_id': tensor([ 4,  3, 10,  3, 20]), 'label': tensor([ 5, 10, 15, 11,  7, 14])}
# {'input_id': tensor([12,  3, 22, 28, 13,  7, 24, 11,  5, 10]), 'label': tensor([ 8, 11, 14, 11, 18, 17, 24])}
# {'input_id': tensor([20, 11,  6,  9, 25,  3, 27]), 'label': tensor([ 4,  3, 24, 11, 14, 11, 16])}
# {'input_id': tensor([15, 17, 14,  5, 10,  3, 16, 21, 13, 27]), 'label': tensor([ 3, 14, 18,  7, 20, 22])}
# {'input_id': tensor([23, 21,  7, 16, 13, 17]), 'label': tensor([ 3, 21, 10, 15,  3, 16])}
# {'input_id': tensor([20, 28,  7, 10,  3, 13]), 'label': tensor([17, 25,  7, 16, 21])}
# {'input_id': tensor([10, 23, 15,  3, 20, 27,  3, 16]), 'label': tensor([13, 14, 17,  7, 22,  7, 16])}
# {'input_id': tensor([27,  3, 13, 17, 24,  5, 10,  7, 16, 13, 17]), 'label': tensor([13, 11, 20,  5, 10, 15,  3])}
# {'input_id': tensor([12,  3, 13, 23,  4, 17, 24]), 'label': tensor([ 7, 24,  3, 20,  7, 21, 22, 17, 24])}
# {'input_id': tensor([14, 27, 28, 11, 16]), 'label': tensor([15, 11, 22, 21, 23, 25,  3])}
# {'input_id': tensor([ 4, 17, 22, 20, 17, 21]), 'label': tensor([22, 21,  3, 14, 11,  7, 24])}
# {'input_id': tensor([ 6, 28, 10,  3, 16, 23, 15, 17, 24]), 'label': tensor([ 9, 20, 17, 21, 21])}
# {'input_id': tensor([18,  7,  8,  3, 16, 11, 21]), 'label': tensor([ 3, 25,  3,  6])}
# {'input_id': tensor([24,  3,  9, 11, 16, 17,  8,  8]), 'label': tensor([15, 11, 14, 16,  7])}
# {'input_id': tensor([ 9, 17, 14, 17, 24,  3, 16, 27, 17, 24]), 'label': tensor([10, 11, 17, 20, 24, 21, 22])}
# {'input_id': tensor([27,  3, 13, 17, 24,  5, 10, 23, 13]), 'label': tensor([21,  5, 10, 17,  8, 11,  7, 14,  6])}
# {'input_id': tensor([15, 23, 14, 22, 27, 13, 10]), 'label': tensor([13,  3, 14, 11, 15,  3, 13, 10, 11])}
# {'input_id': tensor([ 8,  3, 13, 10, 17, 23, 20, 27]), 'label': tensor([25, 11, 14, 14, 11,  3, 15])}
# {'input_id': tensor([ 3,  4,  3,  6, 11]), 'label': tensor([ 6,  7, 15,  3, 14, 14])}
# {'input_id': tensor([20,  7, 27,  7, 20]), 'label': tensor([ 3, 15,  3, 20, 11])}
# {'input_id': tensor([ 4,  3, 13, 11, 22, 21, 13, 11]), 'label': tensor([28, 10, 11,  6, 17, 15, 11, 20, 17, 24])}
# {'input_id': tensor([ 4, 17, 27,  5,  7]), 'label': tensor([16,  3, 12, 12,  3, 20])}
# {'input_id': tensor([ 8,  3, 11, 20, 14, 11,  7]), 'label': tensor([13,  3, 11, 21,  7, 20])}
# {'input_id': tensor([ 3, 22, 22, 11,  3]), 'label': tensor([18, 14, 17, 22, 16, 11,  5, 13, 27])}
# {'input_id': tensor([17,  2, 15,  7,  3, 20,  3]), 'label': tensor([10, 17, 20, 22, 17, 16])}
# {'input_id': tensor([ 8, 17, 20, 21, 22,  7, 20]), 'label': tensor([ 9, 17, 14, 17, 22,  3])}
# {'input_id': tensor([ 4, 20,  7, 28, 17, 24, 12,  3, 13]), 'label': tensor([21,  3, 11, 13, 17, 24])}
# {'input_id': tensor([ 6,  7, 22,  7, 16,  9, 17,  8]), 'label': tensor([21,  3, 14, 24,  3, 27])}
# {'input_id': tensor([16,  3, 22,  3, 20,  7,  7, 24]), 'label': tensor([21,  3, 20, 20,  3,  8])}
# {'input_id': tensor([22,  3, 13,  7, 23,  5, 10, 11]), 'label': tensor([15,  7, 20,  7,  6, 11, 22, 10])}
# {'input_id': tensor([ 3, 25, 20, 23, 21]), 'label': tensor([ 4,  3, 23, 15,  3, 16, 16])}
# {'input_id': tensor([14,  7, 12,  3, 24,  3]), 'label': tensor([ 3,  9,  7, 11, 22,  5, 10, 11, 13])}
# {'input_id': tensor([ 5, 10, 23, 13, 10, 20,  3, 27]), 'label': tensor([12,  3, 18, 18,  3, 20, 17, 24])}
# {'input_id': tensor([ 6, 27, 15, 17, 16,  6]), 'label': tensor([ 3, 21, 25,  3,  6])}
# {'input_id': tensor([12, 23,  4,  4]), 'label': tensor([ 5, 10, 11, 16, 17])}
# {'input_id': tensor([ 6,  7, 20, 27,  3,  4, 13, 11, 16]), 'label': tensor([ 4,  3, 21,  3, 20,  3])}
# {'input_id': tensor([ 4,  7, 20,  7, 28, 17, 24, 21, 13, 27]), 'label': tensor([22, 23, 20,  9,  7, 16,  7, 24])}
# {'input_id': tensor([ 3,  4,  3, 22,  3, 16,  9,  7, 14, 17]), 'label': tensor([15,  3, 20, 22, 27,  3, 16, 17, 24])}
# {'input_id': tensor([16,  3, 10,  3, 21]), 'label': tensor([ 7, 20, 17, 21,  5, 10,  7, 16, 13, 17])}
# {'input_id': tensor([ 3,  4,  4, 17, 23,  6]), 'label': tensor([ 7,  9, 14,  7, 24, 21, 13, 27])}
# {'input_id': tensor([11, 21,  3, 16,  9, 23, 14, 17, 24]), 'label': tensor([ 4, 20, 17,  6,  7, 23, 20])}
# {'input_id': tensor([12,  3, 15, 11, 16, 21, 13, 27]), 'label': tensor([10, 23, 20, 20,  7, 14, 14])}
# {'input_id': tensor([ 4, 11, 20, 13, 11, 16]), 'label': tensor([15,  3,  5, 11, 16, 22, 27, 20,  7])}
# {'input_id': tensor([ 4,  3, 28]), 'label': tensor([11, 22,  3, 15, 11])}
# {'input_id': tensor([10, 17, 25,  7]), 'label': tensor([21, 10,  3, 14, 11, 22, 13, 11, 16])}
# {'input_id': tensor([25, 17, 14,  8,  7]), 'label': tensor([ 3,  9,  3,  4,  7, 13, 17, 24])}
# {'input_id': tensor([25, 11, 28, 16,  7, 20]), 'label': tensor([14, 23, 18, 11,  5, 10,  7, 24])}
# {'input_id': tensor([ 4,  7, 21, 22,  7, 15, 27,  3, 16, 17, 24]), 'label': tensor([ 7,  5, 10,  7, 24,  7, 20, 20, 11,  3])}
# {'input_id': tensor([10, 17, 22,  3, 22,  7]), 'label': tensor([15,  7, 14, 11,  3])}
# {'input_id': tensor([22, 11, 14, 21, 17, 16]), 'label': tensor([ 8, 14,  3, 16,  3,  9,  3, 16])}
# {'input_id': tensor([ 7,  6,  6, 27]), 'label': tensor([ 3, 14,  4,  3, 16, 11])}
# {'input_id': tensor([ 7, 14, 14,  7, 20, 21, 10,  3, 25]), 'label': tensor([17, 10])}
# {'input_id': tensor([ 9,  7, 21, 21,  7, 16]), 'label': tensor([ 4,  3,  9, 14,  3,  7, 16, 13, 17])}
# {'input_id': tensor([16, 17, 17,  6]), 'label': tensor([ 9, 17, 15, 23, 14, 13,  3])}
# {'input_id': tensor([25, 17, 17,  6, 10, 17, 23, 21,  7]), 'label': tensor([ 4,  3,  6,  7, 21,  5, 10,  7, 16, 13, 17, 24])}
# {'input_id': tensor([ 9, 20, 11,  4,  3, 16, 17, 24]), 'label': tensor([14, 27, 21, 11, 13, 17, 24])}
# {'input_id': tensor([22, 17, 23, 15,  3]), 'label': tensor([ 5, 10,  3, 15])}
# {'input_id': tensor([18, 14, 11, 10, 11, 16]), 'label': tensor([10, 17, 18,  7, 21])}
# {'input_id': tensor([10,  3,  6,  6,  3,  6]), 'label': tensor([24,  3, 24, 13, 11, 16])}
# {'input_id': tensor([10,  3, 13, 10, 24,  3]), 'label': tensor([ 5, 17,  4, 23, 20, 16])}
# {'input_id': tensor([ 5, 10,  3, 16,  9]), 'label': tensor([10,  3, 11, 13])}
# {'input_id': tensor([ 4,  3,  3, 20, 14,  7]), 'label': tensor([ 6,  3, 23, 20, 21, 13, 27])}
# {'input_id': tensor([21, 10, 23, 11]), 'label': tensor([ 6, 23,  4, 11, 16, 11, 16])}
# {'input_id': tensor([ 6,  7, 14,  9,  3,  6, 17]), 'label': tensor([28, 17,  4,  3, 16, 17, 24])}
# {'input_id': tensor([14,  7, 25, 20, 27]), 'label': tensor([15, 17,  6,  7, 14])}
# {'input_id': tensor([20,  3, 11, 13,  7, 24, 11,  5, 10]), 'label': tensor([14,  7,  9,  9,  7])}
# {'input_id': tensor([10, 17, 14, 21, 10,  7, 24, 16, 11, 13, 17, 24]), 'label': tensor([ 9, 17, 20,  5, 10,  3, 22, 17, 24])}
# {'input_id': tensor([ 3, 14, 14,  3, 16]), 'label': tensor([ 3,  4,  7, 14, 27,  3, 16])}
# {'input_id': tensor([12, 17, 20, 11, 16]), 'label': tensor([17, 10, 15,  3,  7])}
# {'input_id': tensor([ 3, 22,  3, 15,  3, 16, 27, 23, 13]), 'label': tensor([22,  7, 23,  8,  7, 14])}
# {'input_id': tensor([24,  7, 16, 16,  7, 16]), 'label': tensor([ 9,  7, 10,  8,  7, 16,  4,  3, 23, 15])}
# {'input_id': tensor([20, 17, 23, 21,  7]), 'label': tensor([21, 11,  7, 13,  7, 20, 22])}
# {'input_id': tensor([15, 20,  7, 14,  3, 21, 10, 24, 11, 14, 11]), 'label': tensor([ 3, 14, 11, 16,  3, 20, 11])}
# {'input_id': tensor([ 9,  3, 23]), 'label': tensor([13,  7,  3, 20, 16, 21])}
# {'input_id': tensor([21, 10,  3, 16,  3,  7, 24]), 'label': tensor([27,  3, 16,  9])}
# {'input_id': tensor([ 4, 20,  7, 25,  7, 20]), 'label': tensor([17, 15,  7, 14, 11, 16])}
# {'input_id': tensor([15,  3, 13, 23, 21, 10, 13, 11, 16]), 'label': tensor([14, 23, 17])}
# {'input_id': tensor([ 6,  7, 26, 22,  7, 20]), 'label': tensor([ 3,  4, 28, 27,  3, 18,  3, 20, 17, 24])}
# {'input_id': tensor([24,  3, 21, 11, 16,  6, 11, 16]), 'label': tensor([15, 17, 13,  7, 20, 17, 24])}
# {'input_id': tensor([21, 22,  7, 24,  7, 16, 21]), 'label': tensor([15, 17, 20,  5, 17, 21])}
# {'input_id': tensor([21, 17, 23,  5,  7, 13]), 'label': tensor([ 4, 23,  6,  6])}
# {'input_id': tensor([12,  3, 16, 21, 10, 17, 14,  7]), 'label': tensor([14,  7,  8,  7, 24, 20,  7])}
# {'input_id': tensor([13,  3, 14, 11, 13, 10,  3, 16, 17, 24]), 'label': tensor([ 3,  6,  6,  3, 20, 11, 17])}
# {'input_id': tensor([ 3, 16, 22,  3, 20]), 'label': tensor([13, 10, 17, 23, 20, 11])}
# {'input_id': tensor([10,  3, 20, 22, 23, 13, 17, 24]), 'label': tensor([ 8, 11,  7, 14,  6])}
# {'input_id': tensor([20, 17, 27,  3, 15,  3]), 'label': tensor([ 4,  7, 14, 17])}
# {'input_id': tensor([24, 11, 16, 11,  5, 17, 15,  4,  7]), 'label': tensor([ 4,  3, 28,  7, 16])}
# {'input_id': tensor([21,  5, 10,  7, 16,  5, 13]), 'label': tensor([ 4, 17, 23, 22, 20, 17, 21])}
# {'input_id': tensor([ 3, 22, 14,  3, 16, 22, 17, 24]), 'label': tensor([13, 16, 17, 25, 14,  7, 20])}
# {'input_id': tensor([22,  3, 13,  7, 15, 11, 22, 21, 23]), 'label': tensor([22, 11, 13, 10, 17,  4, 20,  3, 28, 17, 24])}
# {'input_id': tensor([16, 17, 17, 16]), 'label': tensor([ 4, 11, 14, 17, 24])}
# {'input_id': tensor([21, 25,  7,  7, 16,  7, 27]), 'label': tensor([ 3, 25, 20,  3, 15, 22,  5, 10, 11, 13])}
# {'input_id': tensor([28, 10,  3,  9,  3, 14, 11, 16]), 'label': tensor([ 5, 20,  3, 25,  8, 17, 20,  6])}
# {'input_id': tensor([10, 14, 17, 18, 13, 17, 24]), 'label': tensor([10, 17,  8, 15,  3, 16, 16])}
# {'input_id': tensor([11, 16,  9, 14,  7,  4, 27]), 'label': tensor([ 5, 17, 16, 16, 17, 20])}
# {'input_id': tensor([21,  5, 10,  7, 18, 11, 22, 21, 13, 27]), 'label': tensor([ 7, 21, 21, 17, 18])}
# {'input_id': tensor([25, 20, 17, 16, 21, 13, 11]), 'label': tensor([10,  7, 21, 11, 16])}
# {'input_id': tensor([ 4,  3, 14,  3,  9, 23, 14]), 'label': tensor([12, 12,  7, 16, 17, 24])}
# {'input_id': tensor([17, 25,  1, 27,  3, 16,  9]), 'label': tensor([18, 11, 16,  9])}
# {'input_id': tensor([ 6,  3, 24, 11,  6, 21, 17, 16]), 'label': tensor([ 9, 17, 22, 22, 14, 11,  7,  4])}
# {'input_id': tensor([ 3, 22, 13, 11, 16, 21, 17, 16]), 'label': tensor([18, 14, 23, 15, 15,  7, 20])}
# {'input_id': tensor([20, 17,  6,  7, 16]), 'label': tensor([21, 10, 11,  4,  3,  9, 23,  5, 10, 11])}
# {'input_id': tensor([ 4,  3,  4,  3, 20, 11, 16]), 'label': tensor([ 4, 20,  7,  6,  3])}
# {'input_id': tensor([10, 17,  7,  8, 14,  7, 20]), 'label': tensor([21, 17, 23, 22, 10])}
# {'input_id': tensor([ 4,  3,  9, 11, 20, 17,  8,  8]), 'label': tensor([15,  3, 13, 23, 16, 11, 16])}
# {'input_id': tensor([16,  7, 25,  5, 17, 15,  4,  7]), 'label': tensor([20,  3,  6, 14,  7, 27])}
# {'input_id': tensor([24, 27, 21, 17, 22, 21, 13, 11, 10]), 'label': tensor([10,  3, 13, 15,  3, 28,  3])}
# {'input_id': tensor([ 6,  7, 15, 18, 21, 22,  7, 20]), 'label': tensor([18,  7, 14,  7, 24, 11, 16])}
# {'input_id': tensor([ 5, 17, 16, 16,  7,  7, 14, 27]), 'label': tensor([25,  3, 20, 20,  7, 16])}
# {'input_id': tensor([27,  3, 16, 13, 11, 14, 17, 24, 11,  5, 10]), 'label': tensor([ 3,  4,  7, 14, 14, 17])}
# {'input_id': tensor([12,  3,  8,  3,  7, 24]), 'label': tensor([20, 17, 21, 21, 11, 16, 11])}
# {'input_id': tensor([18, 11,  5, 10,  3]), 'label': tensor([ 4,  7, 14,  9, 11,  4,  3,  7, 24])}
# {'input_id': tensor([27,  3, 15, 14, 11, 13, 10,  3, 16, 17, 24]), 'label': tensor([21,  7, 20,  3,  8, 11, 16])}
# {'input_id': tensor([ 9,  7, 20,  9,  7, 21]), 'label': tensor([ 9, 14, 17, 24,  7, 20])}
# {'input_id': tensor([ 6, 23,  4,  3, 21, 17, 24]), 'label': tensor([28, 23,  4, 11, 28,  3, 20, 20,  7, 22,  3])}
# {'input_id': tensor([ 6,  7, 15, 11, 20, 10,  3, 16, 17, 24]), 'label': tensor([21, 24,  7, 12,  6,  3])}
# {'input_id': tensor([ 7, 21, 22, 14, 11,  5, 13]), 'label': tensor([15, 11, 13, 10,  3, 14,  7, 24, 11,  5, 10])}
# {'input_id': tensor([11, 21,  3]), 'label': tensor([21,  3,  8,  3, 20])}
# {'input_id': tensor([17, 14, 11, 24, 11,  7, 20]), 'label': tensor([ 3,  9, 28,  3, 15, 17, 24])}
# {'input_id': tensor([ 3,  4, 11, 10]), 'label': tensor([ 6,  3, 20, 21, 11,  9, 17, 24])}
# {'input_id': tensor([ 4, 11, 21, 10, 17, 18]), 'label': tensor([24, 17, 28,  6, 24, 11, 12,  7, 16, 21, 13, 27])}
# {'input_id': tensor([ 7,  9, 11, 21, 10,  7, 24]), 'label': tensor([16,  3, 12, 12,  3, 20])}
# {'input_id': tensor([21, 10,  3, 11,  6,  3, 13, 17, 24]), 'label': tensor([ 9, 17, 14, 17,  8,  7,  7, 24])}
# {'input_id': tensor([21,  5, 10, 11, 22, 21]), 'label': tensor([16, 11, 21, 10, 11, 17])}
# {'input_id': tensor([15, 23, 28, 20, 23, 13, 17, 24]), 'label': tensor([10, 17, 25,  3, 20,  6])}
# {'input_id': tensor([21, 22,  1, 15,  3, 20, 22, 11, 16]), 'label': tensor([17, 22, 15,  3, 10, 17, 24])}
# {'input_id': tensor([19, 23, 20,  7, 21, 10, 11]), 'label': tensor([15, 17, 16,  8, 17, 20, 22])}
# {'input_id': tensor([12,  7, 16, 17, 24,  3,  5, 10]), 'label': tensor([13, 11, 22, 22])}
# {'input_id': tensor([22, 20, 17, 18, 11, 16, 21, 13, 27]), 'label': tensor([ 9, 10,  3, 16,  7, 15])}
# {'input_id': tensor([13, 11, 20, 22, 14,  7, 27]), 'label': tensor([18, 17, 13, 10, 17,  6, 23, 16])}
# {'input_id': tensor([ 7, 14,  9, 11, 16]), 'label': tensor([27,  3, 16, 13, 17, 24])}
# {'input_id': tensor([10,  3, 17]), 'label': tensor([20, 23,  3,  6, 10])}
# {'input_id': tensor([ 8,  3,  4, 20, 11,  5, 10, 16, 27]), 'label': tensor([ 8,  7, 14, 22, 17, 16])}
# {'input_id': tensor([14, 23, 17]), 'label': tensor([13, 14, 17,  7, 22])}
# {'input_id': tensor([14,  3,  4,  7, 14, 14,  7]), 'label': tensor([16,  3, 10,  3, 21])}
# {'input_id': tensor([22, 28, 11, 17, 14, 13, 17, 24, 21, 13, 27]), 'label': tensor([ 5, 11, 16,  9, 17, 14,  3, 16, 11])}
# {'input_id': tensor([28, 11, 16, 17, 24, 11, 16]), 'label': tensor([ 6, 28, 10, 23, 16, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([12,  3,  5, 10, 15,  7, 16,  7, 24]), 'label': tensor([24, 17, 14, 21, 13, 27])}
# {'input_id': tensor([22, 17, 24, 21, 22, 17, 14, 23, 12, 21, 13, 27]), 'label': tensor([ 6,  7, 20, 13,  3,  5, 10])}
# {'input_id': tensor([ 3,  9,  3, 18, 17, 16, 17, 24]), 'label': tensor([ 4, 17, 20,  6,  7, 14, 17, 16])}
# {'input_id': tensor([ 5,  3,  4, 20,  3, 14]), 'label': tensor([22, 28,  7, 14, 11, 13, 17, 24])}
# {'input_id': tensor([10,  3, 16,  6,  3, 14]), 'label': tensor([14, 17,  3, 22])}
# {'input_id': tensor([ 9, 17, 14, 17, 24]), 'label': tensor([12,  3,  9, 23,  4, 21, 13, 27])}
# {'input_id': tensor([21, 10,  3, 15, 17, 23, 16]), 'label': tensor([12,  3, 20, 20,  3, 15])}
# {'input_id': tensor([27, 23,  3, 21,  3]), 'label': tensor([18,  3, 14, 14,  7, 22, 22])}
# {'input_id': tensor([12,  7, 15,  3, 14,  6, 11, 16, 17, 24]), 'label': tensor([27,  3, 15,  3, 25,  3, 13, 11])}
# {'input_id': tensor([ 3,  4,  3, 11, 15, 17, 24]), 'label': tensor([24, 11, 20, 17, 21, 14,  3, 24, 21, 13, 27])}
# {'input_id': tensor([ 8, 11, 21, 23, 16]), 'label': tensor([ 4,  7, 14, 17, 20, 17, 21, 21, 17, 24])}
# {'input_id': tensor([14, 27, 21,  3, 13, 17, 24]), 'label': tensor([ 6, 17, 16, 16,  5, 10,  3,  6, 10])}
# {'input_id': tensor([13,  3, 21, 18, 20, 28,  3, 13]), 'label': tensor([ 5,  3, 18,  7, 14, 14, 17])}
# {'input_id': tensor([21, 10,  3, 10, 23, 20, 11, 16]), 'label': tensor([22, 17, 15,  3, 16])}
# {'input_id': tensor([17, 20,  7, 14, 14,  3, 16,  3]), 'label': tensor([10,  3, 16, 17, 24])}
# {'input_id': tensor([10,  3, 14,  3,  4, 11]), 'label': tensor([13, 16, 17, 22, 22])}
# {'input_id': tensor([ 6, 17,  9, 23, 28, 17, 24]), 'label': tensor([13, 11, 14, 21, 10,  3, 25])}
# {'input_id': tensor([ 5, 10, 23, 13, 10, 16, 11, 16]), 'label': tensor([16, 23, 16, 16])}
# {'input_id': tensor([ 4,  3, 13, 10, 22,  3,  6, 28,  7]), 'label': tensor([24, 11, 16, 16, 11,  5, 10,  7, 16, 13, 17])}
# {'input_id': tensor([ 9, 11,  4, 21, 17, 16]), 'label': tensor([ 9, 14,  3, 24,  3, 22, 21, 13, 27])}
# {'input_id': tensor([15,  3, 14, 17, 23,  8]), 'label': tensor([10,  3, 18, 17, 24])}
# {'input_id': tensor([12, 11, 24, 17, 18, 11, 21, 22, 21,  7, 24]), 'label': tensor([15, 17, 28, 10,  3, 11, 13, 11, 16])}
# {'input_id': tensor([ 3, 16,  6, 20,  7,  7, 24, 21, 13, 27]), 'label': tensor([ 6,  3, 24,  7, 27])}
# {'input_id': tensor([ 6,  3, 16, 11, 14, 22, 21,  7, 24]), 'label': tensor([ 5, 10,  7, 20, 15,  3, 13])}
# {'input_id': tensor([21,  7,  6,  6, 17, 16]), 'label': tensor([18, 17,  5, 10,  7, 21, 10,  7, 24])}
# {'input_id': tensor([15, 11, 13, 10,  7, 14, 27, 23, 21]), 'label': tensor([15,  3, 22, 28, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([22, 17,  9, 23, 28, 17, 24]), 'label': tensor([15, 23, 16])}
# {'input_id': tensor([10,  3,  4, 11,  5, 10]), 'label': tensor([ 9, 20, 11,  9, 17, 20, 11, 21, 10, 11, 16])}
# {'input_id': tensor([21, 17, 10,  6,  3]), 'label': tensor([ 7,  3, 21, 22,  7, 14, 14])}
# {'input_id': tensor([ 3, 14,  7, 21, 21,  3, 16,  6, 20, 11]), 'label': tensor([21, 14,  7, 11, 15,  3, 16])}
# {'input_id': tensor([17,  3, 13, 21]), 'label': tensor([14, 11, 21, 10, 11, 16])}
# {'input_id': tensor([ 3,  4,  3,  6, 11]), 'label': tensor([21,  3, 20, 13, 11, 21])}
# {'input_id': tensor([ 5,  7, 20, 16, 17, 10, 17, 23, 21]), 'label': tensor([15, 17, 15,  6, 12, 11])}
# {'input_id': tensor([ 8, 20,  3, 16, 13, 14, 11, 16]), 'label': tensor([21, 18,  7,  5, 10, 22])}
# {'input_id': tensor([15, 17, 21, 10, 16, 27,  3, 13, 17, 24]), 'label': tensor([15,  3, 14, 11, 10, 17, 23,  6, 11, 21])}
# {'input_id': tensor([21,  3,  8,  3, 20]), 'label': tensor([ 3, 16, 22, 17, 16,  3, 13, 17, 21])}
# {'input_id': tensor([ 6,  7,  1, 14,  3, 23, 20,  7, 16, 22, 11, 21]), 'label': tensor([ 4, 14,  3, 16,  5, 10,  3, 20,  6])}
# {'input_id': tensor([ 3, 27, 14, 11, 16,  9]), 'label': tensor([24, 11, 14, 14,  3])}
# {'input_id': tensor([ 4,  3, 10,  3, 16, 17, 24]), 'label': tensor([13,  3, 14, 14,  3, 21, 10])}
# {'input_id': tensor([16,  3, 28,  3, 20, 11]), 'label': tensor([12, 11, 24, 17, 22, 17, 24, 21, 13, 27])}
# {'input_id': tensor([ 9, 17, 20,  6, 17, 16]), 'label': tensor([16, 17, 22,  3, 20, 17])}
# {'input_id': tensor([ 6, 28, 10,  3, 16,  3,  7, 24]), 'label': tensor([22, 17, 15,  3])}
# {'input_id': tensor([ 9, 17,  6,  8, 20,  7, 27]), 'label': tensor([22, 17, 22,  3, 10])}
# {'input_id': tensor([ 9, 20,  3,  4, 21, 13, 11]), 'label': tensor([ 9, 11, 14, 14,  7, 22, 22])}
# {'input_id': tensor([ 9, 14, 23,  4, 17, 13, 17, 24, 21, 13, 27]), 'label': tensor([21,  3, 14, 11,  4,  3])}
# {'input_id': tensor([24, 27,  9, 17,  6, 17, 24, 21, 13, 27]), 'label': tensor([18, 27, 21, 10, 11, 16])}
# {'input_id': tensor([21, 10,  3, 10]), 'label': tensor([ 7, 18, 11, 21,  5, 17, 18, 17])}
# {'input_id': tensor([ 4,  3,  9, 15,  7, 22]), 'label': tensor([15,  3, 10, 22, 11,  7, 24])}
# {'input_id': tensor([12,  7, 14, 16, 17, 24]), 'label': tensor([ 3, 21,  3, 16, 23, 15,  3])}
# {'input_id': tensor([15, 23, 28,  3, 14,  7, 24, 21, 13, 11, 13, 10]), 'label': tensor([ 4,  3, 10,  3, 16, 17,  8,  8])}
# {'input_id': tensor([ 4,  7, 20, 22, 11]), 'label': tensor([ 3, 14, 15,  3, 21, 11])}
# {'input_id': tensor([12,  3, 14, 16, 11, 16]), 'label': tensor([25,  7, 20, 20,  7, 22, 22])}
# {'input_id': tensor([20,  3, 10,  3, 14]), 'label': tensor([17,  2,  6, 17, 16, 16,  7, 14, 14])}
# {'input_id': tensor([22, 28,  3, 10]), 'label': tensor([12, 11, 13, 11, 16])}
# {'input_id': tensor([10,  7, 11,  6, 20, 11,  5, 10]), 'label': tensor([ 4, 20, 17, 25, 16, 11, 16,  9])}
# {'input_id': tensor([15,  3, 13, 21, 11, 15, 17, 24]), 'label': tensor([ 8,  3,  4,  7, 14, 11, 16, 21, 13, 27])}
# {'input_id': tensor([24, 27,  4, 17, 20, 16, 17, 24]), 'label': tensor([25,  7, 14, 14, 11, 16,  9, 22, 17, 16])}
# {'input_id': tensor([15,  3, 20, 21, 13, 27]), 'label': tensor([28, 10, 23, 13, 17, 24, 11, 16])}
# {'input_id': tensor([ 9,  3, 16,  7, 15]), 'label': tensor([ 4,  3,  4, 11, 27])}
# {'input_id': tensor([ 4,  3, 13,  3,  7, 24]), 'label': tensor([ 4, 17, 21,  5, 17])}
# {'input_id': tensor([ 3,  6,  3,  6, 23, 20, 17, 24]), 'label': tensor([ 4,  3, 22, 23, 20,  3])}
# {'input_id': tensor([22,  3, 16,  9,  7]), 'label': tensor([13,  3, 21, 21, 11, 21])}
# {'input_id': tensor([18,  3, 20,  3,  6, 12,  3, 16, 17, 24]), 'label': tensor([16,  7, 25, 21, 22,  7,  3,  6])}
# {'input_id': tensor([15, 17, 14, 17, 21, 22, 24, 17, 24]), 'label': tensor([ 3, 15,  3, 27,  3])}
# {'input_id': tensor([14,  7,  7, 23, 25,  7, 16, 10, 17,  7, 13]), 'label': tensor([ 6, 28, 10, 11, 16,  6, 17])}
# {'input_id': tensor([16, 11, 21, 10, 11, 13,  3, 25,  3]), 'label': tensor([ 4,  3, 10, 23, 21, 17, 24])}
# {'input_id': tensor([14, 23, 18,  7, 13, 10, 11, 16]), 'label': tensor([ 3, 20,  3, 23, 12, 17])}
# {'input_id': tensor([ 6, 11,  6,  7, 16, 13, 17]), 'label': tensor([21, 10,  3, 15, 15,  3, 21])}
# {'input_id': tensor([20,  7, 15, 11, 16]), 'label': tensor([22, 17, 22,  3, 10])}
# {'input_id': tensor([17, 14,  6,  8, 11,  7, 14,  6]), 'label': tensor([ 4,  7, 20,  9,  8,  3, 14, 13])}
# {'input_id': tensor([13, 10, 17, 23, 20, 11]), 'label': tensor([15, 11,  8, 21, 23,  6])}
# {'input_id': tensor([12,  3, 20, 15,  3, 16]), 'label': tensor([ 4, 14, 23, 15, 21, 22,  7, 11, 16])}
# {'input_id': tensor([22, 23, 15,  3]), 'label': tensor([21, 10, 11, 15, 23, 28, 23])}
# {'input_id': tensor([ 9,  7, 20,  9,  7, 21]), 'label': tensor([10, 23, 12, 11, 16])}
# {'input_id': tensor([21, 10,  3, 11,  6,  7, 16, 13, 17]), 'label': tensor([15,  5, 16,  3, 15,  3, 20,  3])}
# {'input_id': tensor([ 4,  3, 20,  3, 16, 16, 11, 13, 17, 24]), 'label': tensor([21, 27, 15,  7, 21])}
# {'input_id': tensor([16, 11,  5, 17, 14]), 'label': tensor([24,  3, 11, 16, 21, 17, 16])}
# {'input_id': tensor([ 4, 11,  4, 11, 16]), 'label': tensor([10, 17, 16,  7, 16,  7, 24])}
# {'input_id': tensor([ 6,  7, 20, 11,  4,  3, 21]), 'label': tensor([12, 11,  3])}
# {'input_id': tensor([15, 23, 20,  3, 17, 13,  3]), 'label': tensor([ 8, 11, 16, 16,  7,  9,  3, 16])}
# {'input_id': tensor([15,  3, 22, 21, 23, 21, 10, 11, 22,  3]), 'label': tensor([ 3,  4,  6, 20,  3, 10, 15,  3, 16, 17,  8,  8])}
# {'input_id': tensor([21,  3, 11,  6]), 'label': tensor([ 7, 24,  7, 20,  6,  7, 14, 14])}
# {'input_id': tensor([20,  3, 24,  7, 16]), 'label': tensor([27,  3,  9, 17,  6, 16, 11, 13, 17, 24])}
# {'input_id': tensor([ 9, 11, 14,  7, 21]), 'label': tensor([14, 11,  7, 18,  3])}
# {'input_id': tensor([28,  7, 16, 13, 17, 24, 21, 13, 27]), 'label': tensor([22,  5, 10,  7, 13,  3,  5, 10,  7, 24])}
# {'input_id': tensor([14,  3, 15,  3]), 'label': tensor([28, 17,  4, 17, 24])}
# {'input_id': tensor([21,  7, 22, 17]), 'label': tensor([ 4,  7, 13, 17, 24])}
# {'input_id': tensor([ 4,  3, 20, 17,  5, 10]), 'label': tensor([18, 17,  5, 10, 13, 11, 16])}
# {'input_id': tensor([27, 23]), 'label': tensor([ 3, 16, 22, 20, 17, 18, 17, 24])}
# {'input_id': tensor([24, 11, 14,  6,  3, 16, 17, 24]), 'label': tensor([ 6, 17, 27, 14,  7])}
# {'input_id': tensor([ 8,  7, 14,  6, 22]), 'label': tensor([21, 15,  3, 14, 14])}
# {'input_id': tensor([12,  3, 11, 13,  4,  3,  7, 24]), 'label': tensor([ 4,  3, 28,  3, 20,  7, 24, 11,  5, 10])}
# {'input_id': tensor([10,  7,  3, 22, 17, 16]), 'label': tensor([10,  3, 15,  3, 15, 17, 22, 17])}
# {'input_id': tensor([15, 23, 21, 22,  3,  8,  3]), 'label': tensor([16,  7, 24, 11, 16, 21])}
# {'input_id': tensor([ 9,  3,  9, 16, 11,  7, 20]), 'label': tensor([15, 11, 13, 10,  7, 14, 21, 17, 16])}
# {'input_id': tensor([18, 17, 13, 10, 17, 14, 13, 17, 24]), 'label': tensor([21, 10,  3, 16, 16, 17, 16])}
# {'input_id': tensor([18, 27, 21, 10, 13, 11, 16]), 'label': tensor([ 6, 11,  6, 11,  9, 17, 24])}
# {'input_id': tensor([ 4,  7, 21, 21, 17, 16, 17, 24]), 'label': tensor([18,  3, 28, 27])}
# {'input_id': tensor([22,  7, 23, 15, 11, 16]), 'label': tensor([21, 10,  3, 14,  9, 11, 16])}
# {'input_id': tensor([12,  3, 22, 28,  7, 24, 11,  5, 10]), 'label': tensor([10,  3, 22,  5, 10])}
# {'input_id': tensor([18,  3, 21, 22, 17, 20,  7]), 'label': tensor([17, 13, 11, 15,  3, 21,  3])}
# {'input_id': tensor([ 6,  3, 24, 11,  6]), 'label': tensor([28, 10,  7, 13, 17, 24])}
# ...
# {'input_id': tensor([ 6, 11, 12, 11, 16]), 'label': tensor([16,  3, 18, 18,  7, 20])}
# {'input_id': tensor([11, 28, 23, 15, 11]), 'label': tensor([22, 17,  6, 17, 20, 17, 24, 21, 13, 27])}
# {'input_id': tensor([24,  7, 14, 11, 13, 17, 20, 23, 21, 21, 17, 24]), 'label': tensor([15,  3, 14, 17, 23,  8])}
# {'input_id': tensor([21,  7,  3, 10]), 'label': tensor([24,  7, 16, 16])}
# {'input_id': tensor([18, 17, 16,  3,  8, 11,  6, 11, 16]), 'label': tensor([ 4,  3, 11,  6,  3,  5, 10, 16, 27])}
# {'input_id': tensor([13, 11, 16,  9, 21,  5, 17, 22, 22]), 'label': tensor([ 6,  3, 24, 27,  6,  5, 10,  7, 16, 13, 17, 24])}
# {'input_id': tensor([18, 20, 11, 24,  7, 22, 22]), 'label': tensor([22, 23, 15,  3, 21, 10,  7, 24])}
# {'input_id': tensor([12,  3, 13, 15, 17, 16]), 'label': tensor([ 9,  3,  9, 16,  7])}
# {'input_id': tensor([ 5, 10,  7, 13, 10,  3, 20, 11, 16]), 'label': tensor([ 3,  4,  4,  3, 21, 17, 24])}
# {'input_id': tensor([18,  7, 20, 20, 27]), 'label': tensor([ 3,  6, 27,  3, 16])}
# {'input_id': tensor([20, 27, 12,  7, 16, 13, 17, 24]), 'label': tensor([22,  3, 14, 11, 18, 17, 24])}
# {'input_id': tensor([ 3,  6,  3, 21, 10,  7, 24, 21, 13, 11]), 'label': tensor([20, 11,  5,  5, 11])}
# {'input_id': tensor([20,  3,  6,  8, 17, 20,  6]), 'label': tensor([ 7, 15, 11, 14,  7])}
# {'input_id': tensor([12, 23, 28, 10,  3, 16, 17, 24]), 'label': tensor([15,  3, 20, 27,  5, 10,  7, 24])}
# {'input_id': tensor([ 5, 17, 14,  7]), 'label': tensor([14,  7,  4,  7,  6, 11, 16, 22, 21,  7, 24])}
# {'input_id': tensor([16,  3, 10,  3, 21]), 'label': tensor([24, 11,  5,  3, 20, 11, 17])}
# {'input_id': tensor([ 4, 23, 20,  7,  3, 23]), 'label': tensor([18,  7, 16,  7, 24])}
# {'input_id': tensor([ 4,  3, 13, 10, 22, 11, 16]), 'label': tensor([ 6, 23,  4, 20, 17, 24, 11, 16])}
# {'input_id': tensor([13, 17, 23, 22, 21, 17, 23,  4, 17, 21]), 'label': tensor([ 4,  3,  4,  3,  6, 12,  3, 16, 27,  3, 16])}
# {'input_id': tensor([15, 23, 28,  9, 11, 16]), 'label': tensor([24, 27, 21, 17, 22, 21, 13, 27])}
# {'input_id': tensor([22, 23, 15,  3]), 'label': tensor([15, 11, 10,  7, 14, 21])}
# {'input_id': tensor([13, 20,  3, 16, 28]), 'label': tensor([ 9,  3,  4,  7, 20])}
# {'input_id': tensor([14, 11, 13, 11, 16]), 'label': tensor([14, 11, 13, 10, 17, 24, 22, 21,  7, 24])}
# {'input_id': tensor([ 4,  3,  6, 27, 23, 16, 17, 24]), 'label': tensor([ 7, 16,  7,  7, 24])}
# {'input_id': tensor([12,  3, 13, 17, 24,  7, 22, 21]), 'label': tensor([10,  3,  4, 11,  5, 10,  7, 24])}
# {'input_id': tensor([13, 10,  3, 16]), 'label': tensor([ 4,  3, 22, 22, 27])}
# {'input_id': tensor([ 5, 23, 20, 20,  3, 16]), 'label': tensor([16,  3, 21, 20,  7, 22,  6, 11, 16, 17, 24])}
# {'input_id': tensor([16, 11,  5, 17,  6,  7, 15, 17]), 'label': tensor([ 8, 17, 20,  7, 21, 22])}
# {'input_id': tensor([25, 11, 16, 22,  7, 20]), 'label': tensor([ 6,  7, 20, 13,  3,  5, 10,  7, 24])}
# {'input_id': tensor([16, 17, 20, 24, 11, 14, 14,  7]), 'label': tensor([ 9,  7, 20, 21, 10, 13, 17, 24, 11,  5, 10])}
# {'input_id': tensor([ 3, 20, 15, 11, 22,  3,  9,  7]), 'label': tensor([15, 11, 14, 14, 11,  9,  3, 16])}
# {'input_id': tensor([ 4,  7, 28, 27, 28, 24,  7, 21, 22, 16, 27, 10]), 'label': tensor([ 6, 17, 28, 15, 17, 20, 17, 24])}
# {'input_id': tensor([13, 25,  3, 13]), 'label': tensor([ 7, 14,  7, 10, 11, 16])}
# {'input_id': tensor([21, 20, 17, 23, 20]), 'label': tensor([22,  5, 10,  3, 14,  7,  7, 24])}
# {'input_id': tensor([24,  3, 14, 22,  7, 20, 21]), 'label': tensor([14,  7, 24, 11,  5, 10,  7, 24])}
# {'input_id': tensor([ 7,  3, 20, 14]), 'label': tensor([24, 17,  5, 13, 11, 16, 21])}
# {'input_id': tensor([12, 11, 28, 16, 27,  3, 13, 17, 24]), 'label': tensor([ 8, 23, 20, 22, 21,  5, 10])}
# {'input_id': tensor([ 8, 23, 13, 23, 21, 10, 11, 15,  3]), 'label': tensor([20, 17, 24, 13, 17, 24])}
# {'input_id': tensor([10, 17, 23]), 'label': tensor([24,  7, 14, 11,  9, 12,  3, 16, 11, 16])}
# {'input_id': tensor([21, 22, 17,  5, 13, 14,  7, 27]), 'label': tensor([18,  3, 24, 14, 11, 13])}
# {'input_id': tensor([15, 11,  8, 21, 23,  6]), 'label': tensor([21, 10,  7, 20, 20, 27])}
# {'input_id': tensor([10, 23,  9,  9, 11, 16, 21]), 'label': tensor([ 4,  3,  7, 24, 21, 13, 27])}
# {'input_id': tensor([ 4,  3, 22,  5, 10, 15,  3, 16, 17,  8,  8]), 'label': tensor([ 9,  3, 14,  7, 16, 13, 17, 24])}
# {'input_id': tensor([ 5, 14, 17, 21,  7]), 'label': tensor([10,  7, 20, 20,  7, 20, 17])}
# {'input_id': tensor([24, 27,  3, 28, 17, 24]), 'label': tensor([ 4,  3, 11, 13, 11, 16])}
# {'input_id': tensor([11, 21,  3,  9,  3, 14, 11,  7, 24]), 'label': tensor([16,  3,  9,  3, 10,  3, 15,  3])}
# {'input_id': tensor([27, 11, 15]), 'label': tensor([21, 11, 16,  9, 14,  7, 22, 17, 16])}
# {'input_id': tensor([22, 23, 14, 11, 16, 17, 24]), 'label': tensor([15,  3, 20, 23, 16, 11, 16])}
# {'input_id': tensor([ 3, 24,  7, 20, 13, 11, 16]), 'label': tensor([10, 17, 14, 17,  6, 17, 24])}
# {'input_id': tensor([ 9,  3, 14, 13, 17, 24, 21, 13, 27]), 'label': tensor([15, 11, 16, 11, 22, 21, 13, 27])}
# {'input_id': tensor([ 3, 21, 21,  3,  8]), 'label': tensor([ 6, 17,  9,  7, 14])}
# {'input_id': tensor([ 9, 14,  3, 28, 27, 20, 11, 16]), 'label': tensor([24,  3, 12,  7, 16, 11, 16])}
# {'input_id': tensor([ 3,  4, 17, 24, 11, 16]), 'label': tensor([ 4,  3, 11, 22,  5, 10, 17, 20, 17, 24])}
# {'input_id': tensor([15, 23, 12, 13,  3, 22,  7, 20, 17, 24]), 'label': tensor([ 4,  3, 28, 11, 14,  7, 24, 21, 13, 27])}
# {'input_id': tensor([21,  3, 23, 24,  3,  9,  7, 17, 22]), 'label': tensor([10, 17, 20, 16])}
# {'input_id': tensor([20, 17,  5, 13, 14, 11,  8,  8,  7]), 'label': tensor([ 4,  7, 20, 16,  3, 20,  6])}
# {'input_id': tensor([16,  3, 16,  3, 15, 11]), 'label': tensor([24,  3,  6, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([21,  3, 27,  7,  9, 10]), 'label': tensor([ 8, 14,  3, 22,  7, 20])}
# {'input_id': tensor([21,  5, 10, 20,  3,  6,  7, 20]), 'label': tensor([16, 17, 24, 17, 21,  7, 14, 21, 13, 27])}
# {'input_id': tensor([ 3, 10, 15,  7,  6]), 'label': tensor([16,  3, 10,  3, 15, 13, 11, 21])}
# {'input_id': tensor([12,  7, 14, 22, 17, 23, 10, 17, 24]), 'label': tensor([16, 17,  9, 23,  5, 10, 11])}
# {'input_id': tensor([10,  3, 20, 18,  7, 20]), 'label': tensor([28,  3, 12, 11,  5,  7, 13])}
# {'input_id': tensor([18,  3, 16, 22,  7, 14,  3, 13, 17, 21]), 'label': tensor([ 7, 14, 15,  7, 21])}
# {'input_id': tensor([13,  3, 23, 20]), 'label': tensor([ 3, 14, 17])}
# {'input_id': tensor([12, 23, 20,  3]), 'label': tensor([ 6,  3, 22, 27])}
# {'input_id': tensor([15, 17, 28,  6, 28, 11,  7, 20, 28]), 'label': tensor([28, 10,  7, 14,  7, 28, 16, 27])}
# {'input_id': tensor([13, 17,  9,  3, 20,  3]), 'label': tensor([ 9, 20, 17, 13, 10,  3, 20])}
# {'input_id': tensor([ 3, 20, 11,  3, 16]), 'label': tensor([27,  3, 20, 13,  7, 20])}
# {'input_id': tensor([16, 11,  5, 17, 14, 14]), 'label': tensor([14,  7, 12,  7, 16, 13, 17])}
# {'input_id': tensor([ 6, 17,  4, 20, 17, 24, 21, 13, 27]), 'label': tensor([ 4,  3, 20,  3, 16,  6, 27,  5, 10])}
# {'input_id': tensor([23, 22,  3,  9,  3, 25,  3]), 'label': tensor([21, 18, 17, 16,  7, 20])}
# {'input_id': tensor([ 9,  3, 14, 14, 23, 22,  6, 11, 16, 17, 24]), 'label': tensor([22, 28,  7, 16, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([ 4, 17, 22, 20, 17, 21]), 'label': tensor([ 3,  4,  6, 11, 14,  6, 11, 16])}
# {'input_id': tensor([10,  3, 20,  3, 15,  3, 16]), 'label': tensor([12, 15,  7, 14, 13, 17, 24])}
# {'input_id': tensor([14,  3, 11, 16,  9]), 'label': tensor([ 3, 16, 22, 17, 16, 27, 23, 13])}
# {'input_id': tensor([13, 17, 20, 27,  5,  3, 16]), 'label': tensor([14, 27, 21, 13, 17, 24])}
# {'input_id': tensor([18,  3, 21,  5, 17,  7]), 'label': tensor([28,  3, 21, 23, 10,  3])}
# {'input_id': tensor([ 4,  3, 20, 20, 17, 16]), 'label': tensor([17,  9, 11, 25,  3, 20,  3])}
# {'input_id': tensor([13,  3, 27]), 'label': tensor([15, 17, 28, 10, 11, 16])}
# {'input_id': tensor([10, 23,  6,  7, 13, 17, 24]), 'label': tensor([14, 11, 28, 17, 20, 13, 11, 16])}
# {'input_id': tensor([17, 13,  3, 13, 23, 20,  3]), 'label': tensor([ 5, 23, 22, 22, 21])}
# {'input_id': tensor([ 3,  6, 17, 13, 10, 11, 16]), 'label': tensor([24, 11, 21, 16,  3, 18])}
# {'input_id': tensor([ 8,  3, 13, 10, 17, 23, 20, 27]), 'label': tensor([13, 17, 21, 13, 17])}
# {'input_id': tensor([ 4,  3, 22, 23, 16, 17, 24]), 'label': tensor([22, 10,  7, 14, 25,  7, 14, 14])}
# {'input_id': tensor([ 3, 24,  3, 21, 10]), 'label': tensor([ 4, 17, 20, 14,  3, 16,  6])}
# {'input_id': tensor([ 3,  4, 23,  9, 17, 24]), 'label': tensor([ 3, 21, 13,  7, 20])}
# {'input_id': tensor([10,  3, 16,  6]), 'label': tensor([ 4,  3,  4,  3, 13, 11, 16])}
# {'input_id': tensor([18, 11, 22,  7, 16, 11, 16]), 'label': tensor([10,  3, 14, 11, 13, 17, 24])}
# {'input_id': tensor([13,  3, 22,  3, 27,  3, 15,  3]), 'label': tensor([24,  3, 28, 10, 16, 11,  5, 10, 27])}
# {'input_id': tensor([ 6, 11,  4,  4, 14,  7]), 'label': tensor([21, 10,  3, 14,  3,  7, 24])}
# {'input_id': tensor([18,  3, 25, 14,  3, 13]), 'label': tensor([17, 22, 22,  7, 27])}
# {'input_id': tensor([22, 28,  3, 18,  7, 16, 13, 17]), 'label': tensor([ 5, 10,  7, 20, 22, 17, 20, 11, 22, 21, 13, 27])}
# {'input_id': tensor([24,  7,  6, 27,  3,  7, 24]), 'label': tensor([12,  3, 14, 23, 24, 13,  3])}
# {'input_id': tensor([ 9, 14, 23, 21, 21, 13, 27]), 'label': tensor([27, 17,  7, 15, 17, 16])}
# {'input_id': tensor([6, 7, 7, 4]), 'label': tensor([ 9,  3, 20,  6, 16,  7, 20])}
# {'input_id': tensor([10, 17,  6,  9,  7, 21]), 'label': tensor([24,  7, 16, 22, 23, 20,  3])}
# {'input_id': tensor([10,  3, 14, 23, 22, 11, 16]), 'label': tensor([ 3, 21,  3, 20, 11])}
# {'input_id': tensor([21, 16, 17, 25,  6,  7, 16]), 'label': tensor([24, 11, 14,  9,  7, 14, 15, 11, 16, 11, 16])}
# {'input_id': tensor([13, 10, 17, 23, 20, 27]), 'label': tensor([27,  7,  3, 20,  6, 21, 14,  7, 27])}
# {'input_id': tensor([ 9,  7,  4,  3, 20,  3]), 'label': tensor([ 3, 22, 22, 11,  3])}
# {'input_id': tensor([15, 23,  6, 20,  3, 13]), 'label': tensor([ 5, 10, 23, 13, 10, 20, 17, 24])}
# {'input_id': tensor([14,  7, 11, 13, 17]), 'label': tensor([28, 11, 15,  3, 20, 11, 16])}
# {'input_id': tensor([ 4,  3, 28, 10,  3, 16]), 'label': tensor([24,  3, 14, 11, 21, 10, 11, 16])}
# {'input_id': tensor([22,  5, 10,  7, 13, 17,  7, 24]), 'label': tensor([ 8, 20, 11,  7,  6])}
# {'input_id': tensor([20, 23, 21, 10,  4, 20, 17, 17, 13,  7]), 'label': tensor([13,  7,  3, 20, 22, 17, 16])}
# {'input_id': tensor([ 9, 23, 14, 27,  3, 13]), 'label': tensor([14,  7,  3,  6, 14,  7, 27])}
# {'input_id': tensor([12, 17, 10, 16, 21, 22, 17, 16,  7]), 'label': tensor([27,  3, 16, 17, 24, 11,  5, 10])}
# {'input_id': tensor([10, 17, 20, 11,  9, 17, 15,  7]), 'label': tensor([27,  7,  3, 20,  6, 14,  7, 27])}
# {'input_id': tensor([15, 17, 16, 22,  9, 17, 15,  7, 20, 27]), 'label': tensor([21, 10, 11, 20,  3, 11, 21, 10, 11])}
# {'input_id': tensor([11, 21,  3, 11,  5, 10, 11, 13, 17, 24]), 'label': tensor([28, 10, 11, 22, 16, 27])}
# {'input_id': tensor([28, 17,  4, 13, 17,  4]), 'label': tensor([ 8,  7, 20, 20,  3, 20, 11])}
# {'input_id': tensor([10,  3, 22,  3, 13,  7, 27,  3, 15,  3]), 'label': tensor([ 3,  4,  6, 23, 14,  4,  7, 13, 17,  8,  8])}
# {'input_id': tensor([13, 17, 28, 23]), 'label': tensor([ 9,  3, 16, 11, 15])}
# {'input_id': tensor([ 4, 11, 22,  3, 20]), 'label': tensor([ 6, 23, 20,  3, 21, 17, 24])}
# {'input_id': tensor([ 6, 17,  4, 20, 17, 22, 24, 17, 20, 21, 13, 27]), 'label': tensor([15,  3, 20, 22,  7, 14, 14, 11])}
# {'input_id': tensor([15, 11,  8, 21, 23,  6]), 'label': tensor([18, 11, 22, 23, 10, 11, 16])}
# {'input_id': tensor([13, 11, 13, 23, 11]), 'label': tensor([15, 17, 12, 11, 16])}
# {'input_id': tensor([12,  3, 16,  3, 14, 17, 24]), 'label': tensor([12, 11, 20,  3, 24,  3])}
# {'input_id': tensor([ 4,  3, 11,  6,  3, 24, 14,  7, 22, 17, 24]), 'label': tensor([18,  3, 14,  8, 20,  7, 27])}
# {'input_id': tensor([23, 16, 25, 11, 16]), 'label': tensor([ 9, 10,  3, 16,  7, 15])}
# {'input_id': tensor([ 5, 10,  7, 13, 14,  7, 22, 21, 17, 24]), 'label': tensor([14,  7,  5, 14,  7, 20,  5])}
# {'input_id': tensor([17,  2,  4, 17, 27, 14,  7]), 'label': tensor([16, 23, 21, 21,  7, 16,  4,  3, 23, 15])}
# {'input_id': tensor([14, 11, 24, 21, 10, 11, 22, 28]), 'label': tensor([ 4,  7, 20, 11, 16,  9,  7, 20])}
# {'input_id': tensor([ 4,  3, 22,  5, 10, 23, 20, 11, 16]), 'label': tensor([16,  3,  6,  7, 20])}
# {'input_id': tensor([15,  3, 20, 13, 21]), 'label': tensor([22, 23, 15, 11, 14, 17, 24, 11,  5, 10])}
# {'input_id': tensor([27,  3, 13, 11, 15,  7, 16, 13, 17]), 'label': tensor([14, 11, 10, 17,  6,  7,  7, 24])}
# {'input_id': tensor([20,  7, 13, 11, 22,  3, 20]), 'label': tensor([12,  3, 16, 13, 17, 24, 21, 13, 27])}
# {'input_id': tensor([10, 23,  6,  3, 11,  4,  7, 20,  6, 11, 16]), 'label': tensor([ 9, 23, 14, 11,  7, 24])}
# {'input_id': tensor([21,  3, 14, 11,  4]), 'label': tensor([10, 17, 20, 13, 17, 24])}
# {'input_id': tensor([ 5, 17, 21, 22,  3]), 'label': tensor([ 5, 10,  3,  6, 17, 24, 11,  5, 10])}
# {'input_id': tensor([12,  3, 14,  3, 15, 17, 24]), 'label': tensor([ 9,  3, 16, 11, 15])}
# {'input_id': tensor([15, 11, 13, 10,  3, 11, 14, 11,  5, 10,  7, 16, 13, 17]), 'label': tensor([24, 11, 16,  7, 20])}
# {'input_id': tensor([ 4, 17, 23, 22, 20, 17, 21]), 'label': tensor([ 4,  3, 23, 15,  9,  3, 20, 22, 16,  7, 20])}
# {'input_id': tensor([12, 15, 11, 16, 13, 17]), 'label': tensor([21,  3, 15, 21, 17, 16])}
# {'input_id': tensor([ 8, 14, 27, 16, 16]), 'label': tensor([ 5, 17, 16, 16,  7, 14, 14])}
# {'input_id': tensor([10,  3, 16, 12, 11,  7, 24]), 'label': tensor([20, 23,  3,  6, 10,  3, 16])}
# {'input_id': tensor([10,  3, 13, 10, 23, 14, 11, 16]), 'label': tensor([ 6, 17,  6, 17, 16, 17, 24])}
# {'input_id': tensor([ 3, 16, 11, 16]), 'label': tensor([15, 17, 14,  5,  3, 16, 17, 24, 21])}
# {'input_id': tensor([ 4,  7, 28, 23,  4, 27,  3, 13]), 'label': tensor([15, 17,  9, 11, 14, 16, 11,  5, 10,  7, 16, 13, 17])}
# {'input_id': tensor([13, 17]), 'label': tensor([ 3, 14, 14, 11, 21, 17, 16])}
# {'input_id': tensor([18, 11, 21, 13, 23, 16]), 'label': tensor([10,  3, 20,  4])}
# {'input_id': tensor([13, 11, 16,  5, 10, 11, 16]), 'label': tensor([13, 17, 23, 20, 11])}
# {'input_id': tensor([10, 11, 14,  5, 10,  7, 24, 21, 13, 27]), 'label': tensor([ 6, 12,  3, 14,  6, 12, 11, 20,  7,  7, 24])}
# {'input_id': tensor([ 3, 16, 22, 17, 16]), 'label': tensor([16,  3, 13,  3,  6,  3, 11])}
# {'input_id': tensor([17,  9, 11, 14, 24, 27]), 'label': tensor([16,  3, 21, 14,  7,  6, 16, 11, 13, 17, 24])}
# {'input_id': tensor([21, 10,  7, 14, 27,  3,  9]), 'label': tensor([15, 11, 16, 11,  3, 10, 10, 15,  7, 22, 17, 24])}
# {'input_id': tensor([21, 10,  3, 15, 15,  3, 21]), 'label': tensor([22,  7, 15, 18, 14,  7, 22, 17, 16])}
# {'input_id': tensor([ 9,  3, 23,  7, 20]), 'label': tensor([15, 11, 13, 10, 16, 17, 24])}
# {'input_id': tensor([ 9, 14,  3, 24,  3, 22, 21, 13, 11, 10]), 'label': tensor([ 3, 20,  4, 23,  6, 23])}
# {'input_id': tensor([ 9, 17, 20,  8, 11, 16, 13,  7, 14]), 'label': tensor([22, 21,  7, 13, 10,  3, 16, 17, 24, 11,  5, 10])}
# {'input_id': tensor([ 9, 17, 14, 17, 24,  7, 21, 10, 13, 17]), 'label': tensor([18, 17, 14, 11, 13,  3, 20, 18, 17, 24])}
# {'input_id': tensor([27,  3, 13, 17,  4]), 'label': tensor([21,  3, 14, 11,  4])}
# {'input_id': tensor([10, 17, 14,  3, 16]), 'label': tensor([15,  3, 13, 10, 17, 22, 11, 16])}
# {'input_id': tensor([13, 17, 16,  3,  7]), 'label': tensor([ 8, 20, 11,  7,  6, 20, 11,  5, 10])}
# {'input_id': tensor([ 3, 14, 14,  9, 17, 17,  6]), 'label': tensor([15,  3, 14, 17, 23,  8])}
# {'input_id': tensor([18, 21, 11, 13]), 'label': tensor([18, 11, 16, 11])}
# {'input_id': tensor([ 3,  4, 20,  3, 20, 17,  8,  8]), 'label': tensor([13,  7, 16,  6, 20, 11,  5, 13])}
# {'input_id': tensor([22,  5, 10,  7, 10, 17, 24]), 'label': tensor([16,  7,  9, 20, 11, 16, 11])}
# {'input_id': tensor([ 3, 16,  6, 20, 27, 23, 13, 17, 24]), 'label': tensor([10,  3, 14,  7, 24, 11, 16])}
# {'input_id': tensor([15, 17,  5, 10,  3, 14, 11, 16]), 'label': tensor([ 4,  7, 13, 10])}
# {'input_id': tensor([24,  3, 24, 11,  5, 10]), 'label': tensor([ 7,  3, 21, 22,  7, 20,  4, 20, 17, 17, 13])}

# %%
train_dataloader.batch_size
# Out:
# 4

# %%
def collate_fn(x):
    x_padded = []
    max_len = max([len(r) for r in x])
    for row in x:
      x_padded.append(row + (max_len - len(row))*[0])

    print(x_padded)

# %%
x = (
    [5, 23, 16, 16, 11, 16, 9, 10, 3, 15],
    [3, 9, 3, 18, 17, 8, 8],
    [15, 17, 6, 28, 3, 14, 7, 24, 21, 13, 27],
    [27, 23, 10, 15, 3]
)
print(collate_fn(x))
# Out:
# [[5, 23, 16, 16, 11, 16, 9, 10, 3, 15, 0], [3, 9, 3, 18, 17, 8, 8, 0, 0, 0, 0], [15, 17, 6, 28, 3, 14, 7, 24, 21, 13, 27], [27, 23, 10, 15, 3, 0, 0, 0, 0, 0, 0]]
# None
